# %% [markdown]
# # Tutorial goal

# %% [markdown]
# This tutorial aims to show how to **configure** a **test environment** using
# the **TestEnv module** provided by LISA.

# %% [markdown]
# # Configure logging

# %%
import logging
from conf import LisaLogging
LisaLogging.setup()
# Out:
# 2018-07-10 16:13:13,362 INFO    : root         : Using LISA logging configuration:
# 2018-07-10 16:13:13,363 INFO    : root         :   /home/wz/dev/linaro-dev/lisa/logging.conf

# %%
# Execute this cell to enabled devlib debugging statements
logging.getLogger('ssh').setLevel(logging.DEBUG)

# %%
# Other python modules required by this notebook
import json
import time
import os

# %% [markdown]
# # Test environment setup

# %% [markdown]
# ## Do you have custom scripts to deploy and use on target?

# %%
# Custom scrips must be deployed under $LISA_HOME/tools
# !tree ../../tools
# Out:
# ../../tools
# ├── arm64
# │   ├── perf
# │   ├── README.rt-app
# │   ├── README.taskset
# │   ├── README.trace-cmd
# │   ├── rt-app
# │   ├── sysbench
# │   ├── taskset
# │   └── trace-cmd
# ├── armeabi
# │   ├── perf
# │   ├── README.rt-app
# │   ├── rt-app
# │   ├── sysbench
# │   ├── taskset
# │   └── trace-cmd
# ├── LICENSE.perf
# ├── LICENSE.rt-app
# ├── LICENSE.sysbench
# ├── LICENSE.taskset
# ├── LICENSE.trace-cmd
# ├── plots.py
# ├── report.py
# ├── scripts
# │   ├── cgroup_run_into.sh
# │   ├── cgroup_tasks_move.sh
# │   ├── cpuidle_sampling.sh
# │   ├── odroid_sampler.py
# │   ├── odroid_sampler.sh
# │   └── trace_frequencies.sh
# ├── wa_user_directory
# │   ├── config.yaml
# │   └── plugins
# │       └── ubsystemuijanktests
# │           └── __init__.py
# ├── wltests
# │   ├── agendas
# │   │   ├── example-exoplayer-simple.yaml
# │   │   ├── example-jankbench.yaml
# │   │   ├── example-rich.yaml
# │   │   ├── sched-evaluation-full-traced.yaml
# │   │   ├── sched-evaluation-full.yaml
# │   │   └── sched-evaluation-small.yaml
# │   ├── android
# │   │   ├── create_boot_img.sh
# │   │   ├── create_dt_img.sh
# │   │   ├── mkbootimg
# │   │   ├── mkdtimg
# │   │   └── split_bootimg.pl
# │   ├── build
# │   ├── helpers
# │   ├── platforms
# │   │   ├── hikey620_android-4.4
# │   │   │   ├── build_images
# │   │   │   ├── definitions
# │   │   │   └── flash_images
# │   │   ├── hikey960_android-4.4
# │   │   │   ├── build_images
# │   │   │   ├── definitions
# │   │   │   └── flash_images
# │   │   └── wahoo_android_v4.4
# │   │       ├── build_images
# │   │       ├── definitions
# │   │       └── flash_images
# │   ├── README.md
# │   └── test_series
# ├── workload-automation
# │   ├── dev_scripts
# │   │   ├── clean_install
# │   │   ├── clear_env
# │   │   ├── get_apk_versions
# │   │   ├── pep8
# │   │   ├── pylint
# │   │   ├── README
# │   │   └── rebuild_all_uiauto
# │   ├── doc
# │   │   ├── build_instrument_method_map.py
# │   │   ├── build_plugin_docs.py
# │   │   ├── make.bat
# │   │   ├── Makefile
# │   │   ├── requirements.txt
# │   │   └── source
# │   │       ├── changes.rst
# │   │       ├── conf.py
# │   │       ├── developer_reference
# │   │       │   ├── contributing.rst
# │   │       │   ├── output_processing_api.rst
# │   │       │   ├── revent.rst
# │   │       │   ├── serialization.rst
# │   │       │   └── writing_plugins.rst
# │   │       ├── developer_reference.rst
# │   │       ├── faq.rst
# │   │       ├── how_to.rst
# │   │       ├── how_tos
# │   │       │   ├── developers
# │   │       │   │   └── adding_plugins.rst
# │   │       │   └── users
# │   │       │       ├── agenda.rst
# │   │       │       ├── device_setup.rst
# │   │       │       └── revent.rst
# │   │       ├── index.rst
# │   │       ├── installation.rst
# │   │       ├── instrument_method_map.template
# │   │       ├── migration_guide.rst
# │   │       ├── plugins.rst
# │   │       ├── user_guide.rst
# │   │       ├── user_reference
# │   │       │   ├── configuration.rst
# │   │       │   ├── invocation.rst
# │   │       │   ├── output_directory.rst
# │   │       │   └── runtime_parameters.rst
# │   │       └── user_reference.rst
# │   ├── extras
# │   │   ├── Dockerfile
# │   │   ├── pylintrc
# │   │   ├── README
# │   │   └── walog.vim
# │   ├── LICENSE
# │   ├── MANIFEST.in
# │   ├── README.rst
# │   ├── scripts
# │   │   ├── cpustates
# │   │   └── wa
# │   ├── setup.py
# │   ├── tests
# │   │   ├── data
# │   │   │   ├── bad-syntax-agenda.yaml
# │   │   │   ├── extensions
# │   │   │   │   └── devices
# │   │   │   │       └── test_device.py
# │   │   │   ├── interrupts
# │   │   │   │   ├── after
# │   │   │   │   ├── before
# │   │   │   │   └── result
# │   │   │   ├── logcat.2.log
# │   │   │   ├── logcat.log
# │   │   │   ├── test-agenda.yaml
# │   │   │   └── test-config.py
# │   │   ├── __init__.py
# │   │   ├── test_agenda_parser.py
# │   │   ├── test_config.py
# │   │   ├── test_diff.py
# │   │   ├── test_exec_control.py
# │   │   ├── test_plugin.py
# │   │   ├── test_runtime_param_utils.py
# │   │   ├── test_signal.py
# │   │   └── test_utils.py
# │   └── wa
# │       ├── assets
# │       │   └── bin
# │       │       ├── arm64
# │       │       │   └── revent
# │       │       └── armeabi
# │       │           └── revent
# │       ├── commands
# │       │   ├── create.py
# │       │   ├── __init__.py
# │       │   ├── list.py
# │       │   ├── process.py
# │       │   ├── revent.py
# │       │   ├── run.py
# │       │   ├── show.py
# │       │   └── templates
# │       │       ├── apkrevent_workload
# │       │       ├── apkuiauto_workload
# │       │       ├── apk_workload
# │       │       ├── basic_workload
# │       │       ├── revent_workload
# │       │       ├── setup.template
# │       │       ├── uiauto
# │       │       │   ├── uiauto_AndroidManifest.xml
# │       │       │   ├── uiauto_build.gradle
# │       │       │   ├── uiauto_build_script
# │       │       │   ├── UiAutomation.java
# │       │       │   └── uiauto_workload_template
# │       │       │       ├── build.gradle
# │       │       │       ├── gradle
# │       │       │       │   └── wrapper
# │       │       │       │       ├── gradle-wrapper.jar
# │       │       │       │       └── gradle-wrapper.properties
# │       │       │       ├── gradlew
# │       │       │       ├── gradlew.bat
# │       │       │       └── settings.gradle
# │       │       └── uiauto_workload
# │       ├── framework
# │       │   ├── command.py
# │       │   ├── configuration
# │       │   │   ├── core.py
# │       │   │   ├── default.py
# │       │   │   ├── execution.py
# │       │   │   ├── __init__.py
# │       │   │   ├── parsers.py
# │       │   │   ├── plugin_cache.py
# │       │   │   └── tree.py
# │       │   ├── entrypoint.py
# │       │   ├── exception.py
# │       │   ├── execution.py
# │       │   ├── getters.py
# │       │   ├── host.py
# │       │   ├── __init__.py
# │       │   ├── instrument.py
# │       │   ├── job.py
# │       │   ├── output_processor.py
# │       │   ├── output.py
# │       │   ├── pluginloader.py
# │       │   ├── plugin.py
# │       │   ├── resource.py
# │       │   ├── run.py
# │       │   ├── signal.py
# │       │   ├── target
# │       │   │   ├── assistant.py
# │       │   │   ├── config.py
# │       │   │   ├── descriptor.py
# │       │   │   ├── info.py
# │       │   │   ├── __init__.py
# │       │   │   ├── manager.py
# │       │   │   ├── runtime_config.py
# │       │   │   └── runtime_parameter_manager.py
# │       │   ├── uiauto
# │       │   │   ├── app
# │       │   │   │   ├── build.gradle
# │       │   │   │   └── src
# │       │   │   │       └── main
# │       │   │   │           ├── AndroidManifest.xml
# │       │   │   │           └── java
# │       │   │   │               └── com
# │       │   │   │                   └── arm
# │       │   │   │                       └── wa
# │       │   │   │                           └── uiauto
# │       │   │   │                               ├── ActionLogger.java
# │       │   │   │                               ├── ApplaunchInterface.java
# │       │   │   │                               ├── BaseUiAutomation.java
# │       │   │   │                               ├── UiAutoUtils.java
# │       │   │   │                               └── UxPerfUiAutomation.java
# │       │   │   ├── build.gradle
# │       │   │   ├── build.sh
# │       │   │   ├── gradle
# │       │   │   │   └── wrapper
# │       │   │   │       ├── gradle-wrapper.jar
# │       │   │   │       └── gradle-wrapper.properties
# │       │   │   ├── gradlew
# │       │   │   ├── gradlew.bat
# │       │   │   ├── settings.gradle
# │       │   │   └── uiauto.aar
# │       │   ├── version.py
# │       │   └── workload.py
# │       ├── __init__.py
# │       ├── instruments
# │       │   ├── delay.py
# │       │   ├── dmesg.py
# │       │   ├── energy_measurement.py
# │       │   ├── fps.py
# │       │   ├── hwmon.py
# │       │   ├── __init__.py
# │       │   ├── misc.py
# │       │   ├── poller
# │       │   │   ├── bin
# │       │   │   │   ├── arm64
# │       │   │   │   │   └── poller
# │       │   │   │   └── armeabi
# │       │   │   │       └── poller
# │       │   │   ├── __init__.py
# │       │   │   ├── Makefile
# │       │   │   └── poller.c
# │       │   ├── screencap.py
# │       │   └── trace_cmd.py
# │       ├── output_processors
# │       │   ├── cpustates.py
# │       │   ├── csvproc.py
# │       │   ├── __init__.py
# │       │   ├── sqlite.py
# │       │   ├── status.py
# │       │   ├── targz.py
# │       │   └── uxperf.py
# │       ├── tools
# │       │   └── revent
# │       │       ├── Makefile
# │       │       └── revent.c
# │       ├── utils
# │       │   ├── android.py
# │       │   ├── cpustates.py
# │       │   ├── diff.py
# │       │   ├── doc.py
# │       │   ├── exec_control.py
# │       │   ├── formatter.py
# │       │   ├── __init__.py
# │       │   ├── log.py
# │       │   ├── misc.py
# │       │   ├── revent.py
# │       │   ├── serializer.py
# │       │   ├── terminalsize.py
# │       │   ├── trace_cmd.py
# │       │   └── types.py
# │       └── workloads
# │           ├── adobereader
# │           │   ├── com.arm.wa.uiauto.adobereader.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── adobereader
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── androbench
# │           │   ├── com.arm.wa.uiauto.androbench.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── adobereader
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── angrybirds_rio
# │           │   └── __init__.py
# │           ├── antutu
# │           │   ├── com.arm.wa.uiauto.antutu.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── antutu
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── applaunch
# │           │   ├── com.arm.wa.uiauto.applaunch.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── applaunch
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── benchmarkpi
# │           │   ├── com.arm.wa.uiauto.benchmarkpi.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── benchmarkpi
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── dhrystone
# │           │   ├── bin
# │           │   │   ├── arm64
# │           │   │   │   └── dhrystone
# │           │   │   └── armeabi
# │           │   │       └── dhrystone
# │           │   ├── __init__.py
# │           │   └── src
# │           │       ├── dhrystone.c
# │           │       └── Makefile
# │           ├── exoplayer
# │           │   └── __init__.py
# │           ├── geekbench
# │           │   ├── com.arm.wa.uiauto.geekbench.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── geekbench
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── gmail
# │           │   ├── com.arm.wa.uiauto.gmail.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── gmail
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── googlephotos
# │           │   ├── com.arm.wa.uiauto.googlephotos.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── googlephotos
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── googleplaybooks
# │           │   ├── com.arm.wa.uiauto.googleplaybooks.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── googleplaybooks
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── googleslides
# │           │   ├── com.arm.wa.uiauto.googleslides.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── googleslides
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── hackbench
# │           │   ├── bin
# │           │   │   ├── arm64
# │           │   │   │   └── hackbench
# │           │   │   └── armeabi
# │           │   │       └── hackbench
# │           │   ├── __init__.py
# │           │   └── src
# │           │       └── LICENSE
# │           ├── homescreen
# │           │   └── __init__.py
# │           ├── hwuitest
# │           │   └── __init__.py
# │           ├── idle.py
# │           ├── __init__.py
# │           ├── jankbench
# │           │   └── __init__.py
# │           ├── manual
# │           │   └── __init__.py
# │           ├── meabo
# │           │   └── __init__.py
# │           ├── memcpy
# │           │   ├── bin
# │           │   │   ├── arm64
# │           │   │   │   └── memcpy
# │           │   │   └── armeabi
# │           │   │       └── memcpy
# │           │   ├── __init__.py
# │           │   └── src
# │           │       ├── build.sh
# │           │       └── memcopy.c
# │           ├── openssl
# │           │   └── __init__.py
# │           ├── pcmark
# │           │   ├── com.arm.wa.uiauto.pcmark.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── pcmark
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── recentfling
# │           │   └── __init__.py
# │           ├── rt_app
# │           │   ├── bin
# │           │   │   ├── arm64
# │           │   │   │   └── rt-app
# │           │   │   └── armeabi
# │           │   │       └── rt-app
# │           │   ├── __init__.py
# │           │   ├── LICENSE
# │           │   ├── use_cases
# │           │   │   ├── browser-long.json
# │           │   │   ├── browser-short.json
# │           │   │   ├── camera-long.json
# │           │   │   ├── camera-short.json
# │           │   │   ├── mp3-long.json
# │           │   │   ├── mp3-short.json
# │           │   │   ├── spreading-tasks.json
# │           │   │   ├── taskset.json
# │           │   │   ├── video-long.json
# │           │   │   └── video-short.json
# │           │   └── workgen
# │           ├── shellscript
# │           │   └── __init__.py
# │           ├── speedometer
# │           │   ├── com.arm.wa.uiauto.speedometer.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── speedometer
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── stress_ng
# │           │   ├── bin
# │           │   │   ├── arm64
# │           │   │   │   └── stress-ng
# │           │   │   └── armeabi
# │           │   │       └── stress-ng
# │           │   ├── __init__.py
# │           │   └── LICENSE
# │           ├── sysbench
# │           │   ├── bin
# │           │   │   ├── arm64
# │           │   │   │   └── sysbench
# │           │   │   └── armeabi
# │           │   │       └── sysbench
# │           │   ├── __init__.py
# │           │   └── LICENSE
# │           ├── templerun2
# │           │   └── __init__.py
# │           ├── the_chase
# │           │   └── __init__.py
# │           ├── vellamo
# │           │   ├── com.arm.wa.uiauto.vellamo.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── vellamo
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           ├── youtube
# │           │   ├── com.arm.wa.uiauto.youtube.apk
# │           │   ├── __init__.py
# │           │   └── uiauto
# │           │       ├── app
# │           │       │   ├── build.gradle
# │           │       │   └── src
# │           │       │       └── main
# │           │       │           ├── AndroidManifest.xml
# │           │       │           └── java
# │           │       │               └── com
# │           │       │                   └── arm
# │           │       │                       └── wa
# │           │       │                           └── uiauto
# │           │       │                               └── youtube
# │           │       │                                   └── UiAutomation.java
# │           │       ├── build.gradle
# │           │       ├── build.sh
# │           │       ├── gradle
# │           │       │   └── wrapper
# │           │       │       ├── gradle-wrapper.jar
# │           │       │       └── gradle-wrapper.properties
# │           │       ├── gradlew
# │           │       ├── gradlew.bat
# │           │       └── settings.gradle
# │           └── youtube_playback
# │               └── __init__.py
# └── x86_64
#     ├── perf
#     ├── rt-app
#     ├── sysbench
#     ├── taskset
#     └── trace-cmd
#
# 288 directories, 455 files

# %%
# This is the (not so fancy) script we want to deploy
# !cat ../../tools/scripts/cpuidle_sampling.sh
# Out:
# #!/bin/sh
#
# # CPU to monitor
# CPU=${1:-0}
# # Sampling time
# SLEEP=${2:-1}
# # Samples to collect
# COUNT=${3:-3}
#
# # Enter CPU's sysfs
# cd /sys/devices/system/cpu
#
# # Initial C-State residencies counter
# ISC=$(find cpu0/cpuidle -name "state*" | wc -l)
# for I in $(seq 0 $((ISC-1))); do
# 	LCS[$I]=`cat cpu$CPU/cpuidle/state$I/usage`
# done
#
# # Dump header
# printf "#%13s " "Time"
# for I in $(seq 0 $((ISC-1))); do
#   printf "%14s " "idle$I"
# done
# echo
#
# # Sampling loop
# for I in $(seq $COUNT); do
#
# 	sleep $SLEEP
#
# 	# Dump CPU C-State residencies
# 	now=$(date +%s)
# 	printf "%14d " $now
# 	for I in $(seq 0 $((ISC-1))); do
# 		U=`cat cpu$CPU/cpuidle/state$I/usage`
# 		CCS=$(($U - ${LCS[$I]}))
# 		printf "%14d " $CCS
# 		LCS[$I]=$U
# 	done
# 	echo
#
#
# done
#
# # vim: ts=2

# %% [markdown]
# ## Which devlib modules you need for your experiments?

# %%
# You can have a look at the devlib supported modules by lising the
devlib_modules_folder = 'libs/devlib/devlib/module/'

logging.info("Devlib provided modules are found under:")
logging.info("   $LISA_HOME/{}".format(devlib_modules_folder))
# !cd ../../ ; find {devlib_modules_folder} -name "*.py" | sed 's|libs/devlib/devlib/module/|   |' | grep -v __init__
# Out:
# 2018-07-10 16:13:13,916 INFO    : root         : Devlib provided modules are found under:
# 2018-07-10 16:13:13,918 INFO    : root         :    $LISA_HOME/libs/devlib/devlib/module/
#    cgroups.py
#    hwmon.py
#    biglittle.py
#    hotplug.py
#    android.py
#    cpufreq.py
#    thermal.py
#    cooling.py
#    gem5stats.py
#    vexpress.py
#    gpufreq.py
#    cpuidle.py

# %% [markdown]
# ## Setup you TestEnv confguration

# %%
# Setup a target configuration
conf = {

    # Define the kind of target platform to use for the experiments
    "platform"    : 'android',  # platform type, valid other options are:
                              # android - access via ADB
                              # linux   - access via SSH
                              # host    - direct access
    
    # Preload settings for a specific target
    "board"       : 'sp9863a',   # board type, valid options are:
                              # - juno  - JUNO Development Board
                              # - tc2   - TC2 Development Board
    "device"      : 'SC98631A10183230316',
    # Login credentials
    # "host"        : "192.168.0.1",
    # "username"    : "root",
    # "password"    : "",

    # Custom tools to deploy on target, they must be placed under:
    #   $LISA_HOME/tools/(ARCH|scripts)
    "tools" : [ "cpuidle_sampling.sh" ],

    # FTrace configuration
    "ftrace" : {
         "events" : [
             "cpu_idle",
             "sched_switch",
         ],
         "buffsize" : 10240,
    },
    
    # Where results are collected
    "results_dir" : "TestEnvExample",
    
    # Devlib module required (or not required)
    'modules' : [ "cpufreq", "cgroups" ],
    #"exclude_modules" : [ "hwmon" ],
    
    # Local installation path used for kernel/dtb installation on target
    # The specified path MUST be accessible from the board, e.g.
    # - JUNO/TC2: it can be the mount path of the VMESD disk image
    # - Other board: it can be a TFTP server path used by the board bootloader
    # "tftp"  : {
    #    "folder"    : "/var/lib/tftpboot",
    #    "kernel"    : "kern.bin",
    #    "dtb"       : "dtb.bin",
    # },

}

# %%
from env import TestEnv

# Initialize a test environment using the provided configuration
te = TestEnv(conf)
# Out:
# 2018-07-10 16:13:14,207 INFO    : root         : Generating grammar tables from /usr/lib/python2.7/lib2to3/Grammar.txt
# 2018-07-10 16:13:14,234 INFO    : root         : Generating grammar tables from /usr/lib/python2.7/lib2to3/PatternGrammar.txt
# 2018-07-10 16:13:14,678 INFO    : TestEnv      : Using base path: /home/wz/dev/linaro-dev/lisa
# 2018-07-10 16:13:14,680 INFO    : TestEnv      : Loading custom (inline) target configuration
# 2018-07-10 16:13:14,681 WARNING : TestEnv      : Wipe previous contents of the results folder:
# 2018-07-10 16:13:14,682 WARNING : TestEnv      :    /home/wz/dev/linaro-dev/lisa/results/TestEnvExample
# 2018-07-10 16:13:14,684 INFO    : TestEnv      : External tools using:
# 2018-07-10 16:13:14,686 INFO    : TestEnv      :    ANDROID_HOME: /home/wz/dev/program/android_sdk_ndk/android-sdk-linux
# 2018-07-10 16:13:14,687 INFO    : TestEnv      :    CATAPULT_HOME: /home/wz/dev/linaro-dev/lisa/tools/catapult
# 2018-07-10 16:13:14,689 INFO    : TestEnv      : Loading board:
# 2018-07-10 16:13:14,691 INFO    : TestEnv      :    /home/wz/dev/linaro-dev/lisa/libs/utils/platforms/sp9863a.json
# 2018-07-10 16:13:14,692 INFO    : TestEnv      : Devlib modules to load: [u'bl', u'cpuidle', u'cpufreq', 'cgroups']
# 2018-07-10 16:13:14,696 INFO    : TestEnv      : Connecting Android target [SC98631A10183230316]
# 2018-07-10 16:13:14,698 INFO    : TestEnv      : Connection settings:
# 2018-07-10 16:13:14,699 INFO    : TestEnv      :    {'device': 'SC98631A10183230316'}
# 2018-07-10 16:13:17,556 INFO    : TestEnv      : Initializing target workdir:
# 2018-07-10 16:13:17,560 INFO    : TestEnv      :    /data/local/tmp/devlib-target
# 2018-07-10 16:13:18,205 INFO    : CGroups      : Available controllers:
# 2018-07-10 16:13:18,463 INFO    : CGroups      :   cpuset       : /data/local/tmp/devlib-target/cgroups/devlib_cgh5
# 2018-07-10 16:13:18,747 INFO    : CGroups      :   cpu          : /data/local/tmp/devlib-target/cgroups/devlib_cgh4
# 2018-07-10 16:13:19,040 INFO    : CGroups      :   cpuacct      : /data/local/tmp/devlib-target/cgroups/devlib_cgh1
# 2018-07-10 16:13:19,334 INFO    : CGroups      :   schedtune    : /data/local/tmp/devlib-target/cgroups/devlib_cgh3
# 2018-07-10 16:13:19,624 INFO    : CGroups      :   memory       : /data/local/tmp/devlib-target/cgroups/devlib_cgh2
# 2018-07-10 16:13:19,943 INFO    : CGroups      :   freezer      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-07-10 16:13:20,232 INFO    : CGroups      :   hugetlb      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-07-10 16:13:21,566 INFO    : TestEnv      : Attempting to read energy model from target
# 2018-07-10 16:13:21,862 INFO    : EMReader     : Attempting to load EM using from_sd_target
# 2018-07-10 16:13:23,363 INFO    : TestEnv      : Topology:
# 2018-07-10 16:13:23,366 INFO    : TestEnv      :    [[0, 1, 2, 3], [4, 5, 6, 7]]
# 2018-07-10 16:13:23,608 INFO    : TestEnv      : Loading default EM:
# 2018-07-10 16:13:23,611 INFO    : TestEnv      :    /home/wz/dev/linaro-dev/lisa/libs/utils/platforms/sp9863a.json
# 2018-07-10 16:13:24,362 INFO    : TestEnv      : Enabled tracepoints:
# 2018-07-10 16:13:24,363 INFO    : TestEnv      :    cpu_idle
# 2018-07-10 16:13:24,365 INFO    : TestEnv      :    sched_switch
# 2018-07-10 16:13:24,366 INFO    : TestEnv      : Set results folder to:
# 2018-07-10 16:13:24,367 INFO    : TestEnv      :    /home/wz/dev/linaro-dev/lisa/results/TestEnvExample
# 2018-07-10 16:13:24,369 INFO    : TestEnv      : Experiment results available also in:
# 2018-07-10 16:13:24,370 INFO    : TestEnv      :    /home/wz/dev/linaro-dev/lisa/results_latest

# %% [markdown]
# ## Attributes

# %% [markdown]
# The initialization of the test environment pre-initialize some useful<br>
# environment variables which are available to write test cases.
#
# These are some of the information available via the TestEnv object.

# %%
# The complete configuration of the target we have configured
print json.dumps(te.conf, indent=4)
# Out:
# {
#     "ftrace": {
#         "buffsize": 10240,
#         "events": [
#             "cpu_idle",
#             "sched_switch"
#         ]
#     },
#     "modules": [
#         "cpufreq",
#         "cgroups"
#     ],
#     "results_dir": "TestEnvExample",
#     "platform": "android",
#     "board": "sp9863a",
#     "device": "SC98631A10183230316",
#     "__features__": [],
#     "tools": [
#         "cpuidle_sampling.sh"
#     ]
# }

# %%
# Last configured kernel and DTB image
# print te.kernel
# print te.dtb

# %%
# The IP and MAC address of the target
# print te.ip
# print te.mac

# %%
# A full platform descriptor
print json.dumps(te.platform, indent=4)
# Out:
# {
#     "kernel": {
#         "version_number": 4,
#         "sha1": null,
#         "major": 4,
#         "parts": [
#             4,
#             4,
#             83
#         ],
#         "version": "11 SMP PREEMPT Tue Jul 10 16:02:11 CST 2018",
#         "rc": null,
#         "release": "4.4.83+",
#         "minor": 83
#     },
#     "abi": "arm64",
#     "freqs": {
#         "big": [
#             768000,
#             1050000,
#             1225000,
#             1400000,
#             1500000,
#             1570000
#         ],
#         "little": [
#             768000,
#             884000,
#             1000000,
#             1100000,
#             1200000
#         ]
#     },
#     "nrg_model": {
#         "big": {
#             "cluster": {
#                 "nrg_max": 179
#             },
#             "cpu": {
#                 "cap_max": 1024,
#                 "nrg_max": 352
#             }
#         },
#         "little": {
#             "cluster": {
#                 "nrg_max": 1
#             },
#             "cpu": {
#                 "cap_max": 782,
#                 "nrg_max": 181
#             }
#         }
#     },
#     "clusters": {
#         "big": [
#             4,
#             5,
#             6,
#             7
#         ],
#         "little": [
#             0,
#             1,
#             2,
#             3
#         ]
#     },
#     "cpus_count": 8,
#     "os": "android",
#     "topology": [
#         [
#             0,
#             1,
#             2,
#             3
#         ],
#         [
#             4,
#             5,
#             6,
#             7
#         ]
#     ]
# }

# %%
# A pre-created folder to host the tests results generated using this
# test environment, notice that the suite could add additional information
# in this folder, like for example a copy of the target configuration
# and other target specific collected information
te.res_dir
# Out:
# '/home/wz/dev/linaro-dev/lisa/results/TestEnvExample'

# %%
# The working directory on the target
te.workdir
# Out:
# '/data/local/tmp/devlib-target'

# %% [markdown]
# ## Functions

# %% [markdown]
# Some methods are also exposed to test developers which could be used to easy
# the creation of tests.
#
# These are some of the methods available:

# %%
# Calibrate RT-App (if required) and get the most updated calibration value
te.calibration()

# %%
# Generate a JSON file with the complete platform description
te.platform_dump(dest_dir='/tmp')
# Out:
# ({'abi': 'arm64',
#   'clusters': {'big': [4, 5, 6, 7], 'little': [0, 1, 2, 3]},
#   'cpus_count': 8,
#   'freqs': {'big': [768000, 1050000, 1225000, 1400000, 1500000, 1570000],
#    'little': [768000, 884000, 1000000, 1100000, 1200000]},
#   'kernel': {'major': 4,
#    'minor': 83,
#    'parts': (4, 4, 83),
#    'rc': None,
#    'release': '4.4.83+',
#    'sha1': None,
#    'version': '11 SMP PREEMPT Tue Jul 10 16:02:11 CST 2018',
#    'version_number': 4},
#   'nrg_model': {u'big': {u'cluster': {u'nrg_max': 179},
#     u'cpu': {u'cap_max': 1024, u'nrg_max': 352}},
#    u'little': {u'cluster': {u'nrg_max': 1},
#     u'cpu': {u'cap_max': 782, u'nrg_max': 181}}},
#   'os': 'android',
#   'topology': [[0, 1, 2, 3], [4, 5, 6, 7]]},
#  '/tmp/platform.json')

# %%
# Force a reboot of the target (and wait specified [s] before reconnect)
# te.reboot(reboot_time=60, ping_time=15)

# %%
# Resolve a MAC address into an IP address
# te.resolv_host(host='00:02:F7:00:5A:5B')

# %%
# Copy the specified file into the TFTP server folder defined by configuration
#te.tftp_deploy('/etc/group')

# %%
#!ls -la /var/lib/tftpboot

# %% [markdown]
# # Access to the devlib API

# %% [markdown]
# A special TestEnv attribute is <b>target</b>, which represents a <b>devlib instance</b>.
# Using the target attribute we can access to the full set of devlib provided
# functionalities. Which are summarized in the following sections.

# %% [markdown]
# ## Remotes commands execution

# %%
# Run a command on the target
te.target.execute("echo -n 'Hello Test Environment'", as_root=False)
# Out:
# 'Hello Test Environment'

# %%
# Spawn a command in background on the target
logging.info("Spawn a task which will run for a while...")
process = te.target.kick_off("sleep 10", as_root=True)
# Out:
# 2018-07-10 16:13:25,753 INFO    : root         : Spawn a task which will run for a while...

# %%
output = te.target.execute("ps")
print '\n'.join(output.splitlines())
# Out:
# USER           PID  PPID     VSZ    RSS WCHAN            ADDR S NAME
# root             1     0   12984   2824 0                   0 S init
# root             2     0       0      0 0                   0 S [kthreadd]
# root             3     2       0      0 0                   0 S [ksoftirqd/0]
# root             5     2       0      0 0                   0 S [kworker/0:0H]
# root             7     2       0      0 0                   0 S [rcu_preempt]
# root             8     2       0      0 0                   0 S [rcu_sched]
# root             9     2       0      0 0                   0 S [rcu_bh]
# root            10     2       0      0 0                   0 S [migration/0]
# root            11     2       0      0 0                   0 S [watchdog/0]
# root            12     2       0      0 0                   0 S [watchdog/1]
# root            13     2       0      0 0                   0 S [migration/1]
# root            14     2       0      0 0                   0 S [ksoftirqd/1]
# root            16     2       0      0 0                   0 S [kworker/1:0H]
# root            17     2       0      0 0                   0 S [watchdog/2]
# root            18     2       0      0 0                   0 S [migration/2]
# root            19     2       0      0 0                   0 S [ksoftirqd/2]
# root            21     2       0      0 0                   0 S [kworker/2:0H]
# root            22     2       0      0 0                   0 S [watchdog/3]
# root            23     2       0      0 0                   0 S [migration/3]
# root            24     2       0      0 0                   0 S [ksoftirqd/3]
# root            26     2       0      0 0                   0 S [kworker/3:0H]
# root            27     2       0      0 0                   0 S [watchdog/4]
# root            28     2       0      0 0                   0 S [migration/4]
# root            29     2       0      0 0                   0 S [ksoftirqd/4]
# root            30     2       0      0 0                   0 S [kworker/4:0]
# root            31     2       0      0 0                   0 S [kworker/4:0H]
# root            32     2       0      0 0                   0 S [watchdog/5]
# root            33     2       0      0 0                   0 S [migration/5]
# root            34     2       0      0 0                   0 S [ksoftirqd/5]
# root            35     2       0      0 0                   0 S [kworker/5:0]
# root            36     2       0      0 0                   0 S [kworker/5:0H]
# root            37     2       0      0 0                   0 S [watchdog/6]
# root            38     2       0      0 0                   0 S [migration/6]
# root            39     2       0      0 0                   0 S [ksoftirqd/6]
# root            41     2       0      0 0                   0 S [kworker/6:0H]
# root            42     2       0      0 0                   0 S [watchdog/7]
# root            43     2       0      0 0                   0 S [migration/7]
# root            44     2       0      0 0                   0 S [ksoftirqd/7]
# root            45     2       0      0 0                   0 S [kworker/7:0]
# root            46     2       0      0 0                   0 S [kworker/7:0H]
# root            47     2       0      0 0                   0 S [kdevtmpfs]
# root            48     2       0      0 0                   0 S [suspend_sys_syn]
# root            49     2       0      0 0                   0 S [perf]
# root            50     2       0      0 0                   0 S [irq/6-70500000.]
# root            52     2       0      0 0                   0 S [irq/7-70600000.]
# root            53     2       0      0 0                   0 S [irq/8-70800000.]
# root            54     2       0      0 0                   0 S [irq/9-70900000.]
# root            55     2       0      0 0                   0 S [khungtaskd]
# root            56     2       0      0 0                   0 S [writeback]
# root            57     2       0      0 0                   0 S [ksmd]
# root            58     2       0      0 0                   0 S [crypto]
# root            59     2       0      0 0                   0 S [bioset]
# root            60     2       0      0 0                   0 S [kblockd]
# root            61     2       0      0 0                   0 S [sprd_deep_print]
# root            62     2       0      0 0                   0 S [spi0]
# root            63     2       0      0 0                   0 S [spi5]
# root            64     2       0      0 0                   0 S [edac-poller]
# root            65     2       0      0 0                   0 S [system]
# root            66     2       0      0 0                   0 S [carveout_overla]
# root            67     2       0      0 0                   0 S [carveout_fb]
# root            68     2       0      0 0                   0 D [mbox-send-threa]
# root            69     2       0      0 0                   0 S [devfreq_wq]
# root            70     2       0      0 0                   0 S [cfg80211]
# root            71     2       0      0 0                   0 S [irq/56-spi5.0]
# root            72     2       0      0 0                   0 S [sprdfgu_monitor]
# root            73     2       0      0 0                   0 S [kworker/u16:1]
# root            74     2       0      0 0                   0 S [kworker/0:1]
# root           100     2       0      0 0                   0 S [kswapd0]
# root           101     2       0      0 0                   0 S [vmstat]
# root           102     2       0      0 0                   0 S [fsnotify_mark]
# root           132     2       0      0 0                   0 S [sprd-adf-dev]
# root           133     2       0      0 0                   0 S [bioset]
# root           134     2       0      0 0                   0 S [bioset]
# root           135     2       0      0 0                   0 S [bioset]
# root           136     2       0      0 0                   0 S [bioset]
# root           137     2       0      0 0                   0 S [bioset]
# root           138     2       0      0 0                   0 S [bioset]
# root           139     2       0      0 0                   0 S [bioset]
# root           140     2       0      0 0                   0 S [bioset]
# root           141     2       0      0 0                   0 S [bioset]
# root           142     2       0      0 0                   0 S [bioset]
# root           143     2       0      0 0                   0 S [bioset]
# root           144     2       0      0 0                   0 S [bioset]
# root           145     2       0      0 0                   0 S [bioset]
# root           146     2       0      0 0                   0 S [bioset]
# root           147     2       0      0 0                   0 S [bioset]
# root           148     2       0      0 0                   0 S [bioset]
# root           149     2       0      0 0                   0 S [bioset]
# root           150     2       0      0 0                   0 S [bioset]
# root           151     2       0      0 0                   0 S [bioset]
# root           152     2       0      0 0                   0 S [bioset]
# root           153     2       0      0 0                   0 S [bioset]
# root           154     2       0      0 0                   0 S [bioset]
# root           155     2       0      0 0                   0 S [bioset]
# root           156     2       0      0 0                   0 S [bioset]
# root           157     2       0      0 0                   0 S [bioset]
# root           158     2       0      0 0                   0 S [saudio]
# root           159     2       0      0 0                   0 S [saudio-5-10]
# root           160     2       0      0 0                   0 S [saudio]
# root           161     2       0      0 0                   0 S [sblock-5-13]
# root           162     2       0      0 0                   0 S [sblock-5-10]
# root           163     2       0      0 0                   0 S [saudio-5-14]
# root           164     2       0      0 0                   0 S [sblock-5-11]
# root           165     2       0      0 0                   0 S [sblock-5-12]
# root           166     2       0      0 0                   0 S [sblock-5-131]
# root           167     2       0      0 0                   0 S [sblock-5-17]
# root           168     2       0      0 0                   0 S [memory_wq]
# root           169     2       0      0 0                   0 S [sblock-5-14]
# root           170     2       0      0 0                   0 S [sblock-5-15]
# root           171     2       0      0 0                   0 S [sblock-5-16]
# root           172     2       0      0 0                   0 S [sblock-5-151]
# root           173     2       0      0 0                   0 S [uether]
# root           174     2       0      0 0                   0 S [mas_workqueue]
# root           175     2       0      0 0                   0 S [gsp-core[0]]
# root           176     2       0      0 0                   0 S [dm_bufio_cache]
# root           177     2       0      0 0                   0 S [cfinteractive]
# root           179     2       0      0 0                   0 S [sugov:4]
# root           180     2       0      0 0                   0 S [sprdhotplug]
# root           181     2       0      0 0                   0 S [kworker/0:2]
# root           182     2       0      0 0                   0 S [irq/67-20300000]
# root           183     2       0      0 0                   0 S [bioset]
# root           184     2       0      0 0                   0 S [sbuf-6-4]
# root           185     2       0      0 0                   0 S [sbuf-6-5]
# root           186     2       0      0 0                   0 S [sbuf-6-6]
# root           187     2       0      0 0                   0 S [sbuf-5-4]
# root           188     2       0      0 0                   0 S [mmcqd/0]
# root           189     2       0      0 0                   0 S [bioset]
# root           190     2       0      0 0                   0 S [mmcqd/0boot0]
# root           191     2       0      0 0                   0 S [bioset]
# root           192     2       0      0 0                   0 S [sbuf-5-21]
# root           193     2       0      0 0                   0 S [mmcqd/0boot1]
# root           194     2       0      0 0                   0 S [sbuf-5-6]
# root           195     2       0      0 0                   0 S [bioset]
# root           196     2       0      0 0                   0 S [mmcqd/0rpmb]
# root           197     2       0      0 0                   0 S [sbuf-4-4]
# root           198     2       0      0 0                   0 S [sblock-5-5]
# root           199     2       0      0 0                   0 S [swcnblk-3-7]
# root           200     2       0      0 0                   0 S [swcnblk-3-8]
# root           201     2       0      0 0                   0 S [swcnblk-3-9]
# root           203     2       0      0 0                   0 S [kworker/5:1]
# root           204     2       0      0 0                   0 S [kworker/6:1]
# root           205     2       0      0 0                   0 S [binder]
# root           206     2       0      0 0                   0 S [kworker/7:1]
# root           207     2       0      0 0                   0 S [kworker/2:1]
# root           208     2       0      0 0                   0 S [kworker/1:1]
# root           209     2       0      0 0                   0 S [kworker/3:1]
# root           210     2       0      0 0                   0 S [kworker/u16:2]
# root           211     2       0      0 0                   0 S [ipv6_addrconf]
# root           212     2       0      0 0                   0 S [sblock-5-2]
# root           213     2       0      0 0                   0 S [imsbr-data[5-2]]
# root           214     2       0      0 0                   0 S [sblock-5-3]
# root           215     2       0      0 0                   0 S [imsbr-ctrl[5-3]]
# root           225     2       0      0 0                   0 S [deferwq]
# root           226     2       0      0 0                   0 S [sipx-5-7]
# root           227     2       0      0 0                   0 S [sipx-5-8]
# root           228     2       0      0 0                   0 S [sipx-5-9]
# root           229     2       0      0 0                   0 S [sipx-5-18]
# root           230     2       0      0 0                   0 S [sipx-5-19]
# root           231     2       0      0 0                   0 S [sipx-5-20]
# root           232     2       0      0 0                   0 S [sipx-5-24]
# root           233     2       0      0 0                   0 S [sipx-5-25]
# root           234     2       0      0 0                   0 S [shub_synctime]
# root           235     2       0      0 0                   0 S [shub_rd]
# root           236     2       0      0 0                   0 S [shub_rd_nwu]
# root           237     2       0      0 0                   0 S [sbuf-3-4]
# root           238     2       0      0 0                   0 S [sbuf-3-11]
# root           239     2       0      0 0                   0 S [sbuf-3-12]
# root           240     2       0      0 0                   0 S [sbuf-3-5]
# root           241     2       0      0 0                   0 S [irq/74-adaptive]
# root           242     2       0      0 0                   0 S [adaptive_ts_wor]
# root           243     2       0      0 0                   0 S [adaptive_ts_not]
# root           244     2       0      0 0                   0 S [sprdbat_monitor]
# root           246     2       0      0 0                   0 S [kworker/u16:5]
# root           247     2       0      0 0                   0 S [headset_button]
# root           248     2       0      0 0                   0 S [headset_detect_]
# root           249     2       0      0 0                   0 S [headset_reg_dum]
# root           250     2       0      0 0                   0 S [kworker/0:1H]
# root           251     2       0      0 0                   0 S [jbd2/mmcblk0p28]
# root           252     2       0      0 0                   0 S [ext4-rsv-conver]
# root           253     2       0      0 0                   0 S [jbd2/mmcblk0p30]
# root           254     2       0      0 0                   0 S [ext4-rsv-conver]
# root           255     1    6072   1912 0                   0 S ueventd
# root           264     2       0      0 0                   0 S [f_mtp]
# root           265     2       0      0 0                   0 S [VserTestWq]
# root           274     2       0      0 0                   0 S [jbd2/mmcblk0p29]
# root           275     2       0      0 0                   0 S [ext4-rsv-conver]
# root           277     2       0      0 0                   0 S [jbd2/mmcblk0p1-]
# root           278     2       0      0 0                   0 S [ext4-rsv-conver]
# logd           279     1   20932   5636 0                   0 S logd
# system         280     1   10448   3480 0                   0 S servicemanager
# system         281     1   14440   5768 0                   0 S hwservicemanager
# system         282     1   10244   3068 0                   0 S vndservicemanager
# root           288     2       0      0 0                   0 S [kauditd]
# root           290     2       0      0 0                   0 S [pvr_timer]
# root           291     2       0      0 0                   0 S [pvr_defer_free]
# root           292     2       0      0 0                   0 S [pvr_device_wdg]
# root           293     2       0      0 0                   0 S [pvr_cacheop]
# root           294     2       0      0 0                   0 S [pvr_sync_defer_]
# root           295     2       0      0 0                   0 S [pvr_sync_check_]
# system         296     1   13884   5016 0                   0 S android.hardware.keymaster@3.0-service
# root           298     1   59012   8076 0                   0 S vold
# system         304     1  154756   9620 0                   0 S ylog
# root           305     1   20044   4220 0                   0 S collect_apr
# system         312     1   12096   3824 0                   0 S android.hidl.allocator@1.0-service
# audioserver    313     1   30304  10932 0                   0 S android.hardware.audio@2.0-service
# bluetooth      314     1   12228   4160 0                   0 S android.hardware.bluetooth@1.0-service
# cameraserver   315     1   45696  13372 0                   0 S android.hardware.camera.provider@2.4-service
# media          316     1   12276   4684 0                   0 S android.hardware.cas@1.0-service
# system         317     1   15380   4024 0                   0 S android.hardware.configstore@1.0-service
# media          318     1   15864   7256 0                   0 S android.hardware.drm@1.0-service
# media          319     1   14368   5628 0                   0 S android.hardware.drm@1.0-service.widevine
# system         320     1   12096   3900 0                   0 S android.hardware.dumpstate@1.0-service
# system         321     1   12196   4076 0                   0 S android.hardware.gatekeeper@1.0-service
# system         322     1   19096   4708 0                   0 S android.hardware.graphics.allocator@2.0-service
# system         323     1   57008  15036 0                   0 S android.hardware.graphics.composer@2.1-service
# system         324     1   12120   4080 0                   0 S android.hardware.health@1.0-service
# system         325     1   12152   4072 0                   0 S android.hardware.light@2.0-service
# system         326     1   12132   4104 0                   0 S android.hardware.memtrack@1.0-service
# system         327     1   13252   3852 0                   0 S android.hardware.usb@1.0-service
# system         328     1   12148   4012 0                   0 S android.hardware.vibrator@1.0-service
# root           329     1   14560   5752 0                   0 S android.hardware.wifi@1.0-service
# system         330     1   12352   4160 0                   0 S vendor.sprd.hardware.connmgr@1.0-service
# system         339     1   12344   4296 0                   0 S vendor.sprd.hardware.enhance@1.0-service
# system         356     1   15584   4420 0                   0 S vendor.sprd.hardware.face@1.0-service
# system         357     1   12316   4160 0                   0 S vendor.sprd.hardware.ifaa@1.0-service
# system         358     1   15444   4048 0                   0 S vendor.sprd.hardware.log@1.0-service
# root           359     1   24192   9580 0                   0 S vendor.sprd.hardware.power@2.0-service
# system         360     1   12460   4500 0                   0 S vendor.sprd.hardware.thermal@1.0-service
# root           361     1   18416   5540 0                   0 S healthd
# system         362     1   10992   2620 0                   0 S gpsd
# root           363     1   31956  12432 0                   0 S engpc
# root           364     1   12564   6084 0                   0 S lmkd
# root           365     1   20640   4520 0                   0 S performancemanager
# root           367     2       0      0 0                   0 S [pvr_workqueue]
# root           368     2       0      0 0                   0 S [pvr_workqueue]
# system         369     1   65984  20496 0                   0 S surfaceflinger
# root           372     2       0      0 0                   0 S [pvr_workqueue]
# root           374     1   22760   5852 0                   0 S thermalserviced
# system         375     1   16280   3008 0                   0 S modem_control
# system         377     1   12176   2568 0                   0 S modemd
# system         378     1    8904   2508 0                   0 S sprdstorageproxyd
# system         379     1    9936   3256 0                   0 S tsupplicant
# root           416     2       0      0 0                   0 S [kworker/1:1H]
# root           470     2       0      0 0                   0 S [kdmflush]
# root           478     2       0      0 0                   0 S [bioset]
# root           479     2       0      0 0                   0 S [kcryptd_io]
# root           481     2       0      0 0                   0 S [kworker/u17:0]
# root           482     2       0      0 0                   0 S [kcryptd]
# root           483     2       0      0 0                   0 S [dmcrypt_write]
# root           484     2       0      0 0                   0 S [bioset]
# root           487   304   14956   6428 0                   0 S tcpdump
# root           488   304    9004   2672 0                   0 S hcidump
# root           490   304   11976   2844 0                   0 S iodebug
# system         493   304    8788   2764 0                   0 S sgm.cpu_memory
# root           517     2       0      0 0                   0 S [kworker/2:1H]
# radio          529     1   42288   8384 0                   0 S sprdrild
# root           530     1   21292   9732 0                   0 S cp_diskserver
# root           586     2       0      0 0                   0 S [kworker/6:2]
# root           591     2       0      0 0                   0 S [kworker/2:2]
# root           594     2       0      0 0                   0 S [kworker/u17:1]
# root           595     2       0      0 0                   0 S [kworker/u17:2]
# shell          607     1   13988   1496 0              4c5040 R adbd
# root           611     2       0      0 0                   0 S [kworker/1:2]
# root           617     2       0      0 0                   0 S [f2fs_flush-252:]
# root           618     2       0      0 0                   0 S [f2fs_discard-25]
# root           620     2       0      0 0                   0 S [f2fs_gc-252:0]
# root           626     1    9664   2972 0                   0 S srtd
# root           627     1 4245100 127388 0                   0 S zygote64
# root           628     1 1586748 113872 0                   0 S zygote
# audioserver    629     1   36340  12368 0                   0 S audioserver
# cameraserver   630     1   25604  11052 0                   0 S cameraserver
# drm            631     1 2159320  26328 0                   0 S drmserver
# root           632     1    9100   2680 0                   0 S ims_bridged
# root           633     1   23712   6056 0                   0 S installd
# keystore       634     1   24232   7124 0                   0 S keystore
# root           635     1   11912   3880 0                   0 S log_service
# media          636     1   13920   6108 0                   0 S mediadrmserver
# root           637   626    9920    588 0                   0 S srtd
# mediaex        638     1 2161980  19176 0                   0 S media.extractor
# media          639     1 2128328  10964 0                   0 S media.metrics
# media          640     1   49164  13344 0                   0 S mediaserver
# root           641     1   36880   7128 0                   0 S netd
# system         643     1   15432   4412 0                   0 S phasecheckserver
# root           644     1   20956   4864 0                   0 S storaged
# wifi           645     1   20044   6320 0                   0 S wificond
# mediacodec     646     1   39520  11560 0                   0 S media.codec
# system         647     1   15468   4524 0                   0 S android.hardware.sensors@1.0-service
# root           648     1    8668   2656 0                   0 S ext_data
# system         649     1   13252   3056 0                   0 S refnotify
# shell          650     1   21772   3848 0                   0 S slogmodem
# system         651     1   31164   9316 0                   0 S thermald
# system         654     1   52992  16112 0                   0 S vendor.sprd.hardware.gnss@1.0-service
# system         655     1   20508   6612 0                   0 S gatekeeperd
# tombstoned     656     1    9032   2692 0                   0 S tombstoned
# system         657     1   12912   4364 0                   0 S android.hardware.biometrics.fingerprint@2.1-service
# root           658     2       0      0 0                   0 S [irq/69-SPRDSens]
# system         659     1    8904   2648 0                   0 S sprdstorageproxyd
# system         660     1   19916   9004 0                   0 S connmgr
# root           674     1   10420   3324 0                   0 S dsd
# root           681     2       0      0 0                   0 S [kworker/5:1H]
# root           683   641    9456   3276 0                   0 S iptables-restore
# root           685   641    9472   3212 0                   0 S ip6tables-restore
# root           706     2       0      0 0                   0 S [kworker/7:1H]
# root           733     2       0      0 0                   0 S [kworker/3:1H]
# system         835   627 4530596 222628 0                   0 S system_server
# radio         1016   627 4393984 136316 0                   0 S com.android.phone
# u0_a84        1053   627 4335100  87800 0                   0 S com.android.inputmethod.latin
# u0_a22        1069   627 4477212 190568 0                   0 S com.android.systemui
# webview_zygote 1124    1 1335872  52524 0                   0 S webview_zygote32
# system        1281   627 4380776 114504 0                   0 S com.android.settings
# system        1509   627 4319768  66208 0                   0 S com.sprd.applock
# system        1523   627 4337964  78776 0                   0 S com.spreadtrum.vce
# system        1537   627 4321528  63716 0                   0 S com.sprd.udpDataStall
# system        1551   627 4320596  66048 0                   0 S com.sprd.commlog
# u0_a87        1564   627 4321640  61556 0                   0 S com.android.modemnotifier
# u0_a13        1623   627 4399004 145836 0                   0 S com.android.launcher3
# u0_a81        1642   627 4319452  61776 0                   0 S com.android.smspush
# system        1707   627 4330344  86996 0                   0 S com.android.deskclock
# u0_a27        1731   627 4331184  72688 0                   0 S com.android.gallery3d
# u0_a10        1765   627 4334844 103064 0                   0 S android.process.media
# u0_a4         1813   627 4339412  78244 0                   0 S com.android.dialer
# u0_a4         1835   627 4335920  91988 0                   0 S android.process.acore
# u0_a82        1862   627 4324468  70424 0                   0 S com.android.calendar
# u0_a4         1885   627 4328336  70696 0                   0 S com.android.contacts
# u0_a66        1905   627 4346268  85160 0                   0 S com.android.email
# u0_a48        1921   627 4326352  71320 0                   0 S com.android.exchange
# u0_a60        1978   627 4335656  83692 0                   0 S com.android.messaging
# u0_a23        2028   627 4325636  65972 0                   0 S com.android.packageinstaller
# u0_a20        2044   627 4321376  74668 0                   0 S com.android.providers.calendar
# root          2068     2       0      0 0                   0 S [kworker/4:2]
# u0_a46        2071   627 4323880  67148 0                   0 S com.android.soundrecorder
# system        2089   627 4337072  86120 0                   0 S com.sprd.engineermode
# system        2115   627 4318768  64724 0                   0 S com.sprd.systemupdate
# system        2134   627 4318512  63296 0                   0 S com.spreadst.validator
# u0_a80        2158   627 4325932  72296 0                   0 S com.android.quicksearchbox
# u0_a2         2178   627 4321412  69752 0                   0 S com.android.cellbroadcastreceiver
# u0_a8         2477   627 4322048  69080 0                   0 S android.ext.services
# root          2615     2       0      0 0                   0 S [kworker/3:2]
# system        2625   627 4320652  63620 0                   0 S com.android.keychain
# root          3174     2       0      0 0                   0 S [kworker/0:0]
# root          3193     2       0      0 0                   0 S [kworker/2:0]
# root          3307     2       0      0 0                   0 S [kworker/1:0]
# root          3364     2       0      0 0                   0 S [kworker/4:1]
# root          3365     2       0      0 0                   0 S [kworker/5:2]
# root          3366     2       0      0 0                   0 S [kworker/3:0]
# root          4162     2       0      0 0                   0 S [kworker/u16:0]
# root          4201     2       0      0 0                   0 S [kworker/6:0]
# root          4310   490    8936   2612 0                   0 S sh
# root          4313  4310    8936   2940 0                   0 S sh
# root          4326  4313    8936    544 0                   0 S sh
# root          4327  4313    2092      4 0                   0 S busybox
# root          4329  4326   10508   3260 0                   0 S sleep
# root          4456     2       0      0 0                   0 S [kworker/u17:3]
# root          4629     1    8936    516 0                   0 S sh
# root          4630  4629   10508   3372 0                   0 S sleep
# shell         4631   607    8936   2604 sigsuspend 6fc4435784 S sh
# shell         4633  4631   10508   3400 0          706974f0e4 R ps

# %% [markdown]
# Notice that _the Shell PID is always the same_ for all commands we execute.<br>
# This is due to devlib ensuring to keep a **persistent connection** with the target device.

# %% [markdown]
# ## Running custom scripts

# %%
my_script = te.target.get_installed("cpuidle_sampling.sh")
print my_script
# Out:
# /data/local/tmp/bin/cpuidle_sampling.sh

# %%
output = te.target.execute(my_script, as_root=True)
output.splitlines()
# Out:
# ['#         Time          idle0          idle1 ',
#  '    1325713246            136             47 ',
#  '    1325713247             89             33 ',
#  '    1325713248            105             30 ']

# %% [markdown]
# Notice that the output is returned as a **list of lines**. This provides a useful base for post-processing the output of that command.

# %%
# We can also use "notebook embedded" scripts
# my_script = " \
# for I in $(seq 3); do \
#     grep '' /sys/devices/system/cpu/cpu*/cpufreq/stats/time_in_stats | \
#     sed -e 's|/sys/devices/system/cpu/cpu||' -e 's|/cpufreq/scaling_governor:| |' \
#     sleep 1 \
# done \
# "

# %%
# print te.target.execute(my_script)

# %% [markdown]
# ## Access to target specific attributes

# %%
# Acces to many target specific information
print "ABI                 : ", te.target.abi
print "big Core Family     : ", te.target.big_core
print "LITTLE Core Family  : ", te.target.little_core
print "CPU's Clusters IDs  : ", te.target.core_clusters
print "CPUs type           : ", te.target.core_names
# Out:
# ABI                 :  arm64
# big Core Family     :  A55_1
# LITTLE Core Family  :  A55_0
# CPU's Clusters IDs  :  [0, 0, 0, 0, 1, 1, 1, 1]
# CPUs type           :  [u'A55_0', u'A55_0', u'A55_0', u'A55_0', u'A55_1', u'A55_1', u'A55_1', u'A55_1']

# %%
# Access to big.LITTLE specific information
print "big CPUs IDs        : ", te.target.bl.bigs
print "LITTLE CPUs IDs     : ", te.target.bl.littles
print "big CPUs freqs      : {}".format(te.target.bl.get_bigs_frequency())
print "big CPUs governor   : {}".format(te.target.bl.get_bigs_governor())
# Out:
# big CPUs IDs        :  [4, 5, 6, 7]
# LITTLE CPUs IDs     :  [0, 1, 2, 3]
# big CPUs freqs      : 1570000
# big CPUs governor   : schedutil

# %% [markdown]
# ## Modules usage example: CPUFreq

# %%
# You can use autocompletion to have a look at the supported method for a
# specific module
te.target.cpufreq #.get_all_governors()

# %%
# Get goverors available for CPU0
te.target.cpufreq.list_governors(0)
# Out:
# ['interactive',
#  'ondemand',
#  'userspace',
#  'powersave',
#  'performance',
#  'schedutil']

# %%
# Set the "ondemand" governor
te.target.cpufreq.set_governor(0, 'ondemand')

# %%
# Check governor tunables
te.target.cpufreq.get_governor_tunables(0)
# Out:
# {'ignore_nice_load': '0',
#  'io_is_busy': '0',
#  'powersave_bias': '0',
#  'sampling_down_factor': '1',
#  'sampling_rate': '2000000',
#  'sampling_rate_min': '10000',
#  'up_threshold': '95'}

# %%
# Update governor tunables
te.target.cpufreq.set_governor_tunables(0, sampling_rate=2000000)
te.target.cpufreq.get_governor_tunables(0)
# Out:
# {'ignore_nice_load': '0',
#  'io_is_busy': '0',
#  'powersave_bias': '0',
#  'sampling_down_factor': '1',
#  'sampling_rate': '2000000',
#  'sampling_rate_min': '10000',
#  'up_threshold': '95'}

# %% [markdown]
# ## Modules usage example: CGroups

# %%
logging.info('%14s - Available controllers:', 'CGroup')
ssys = te.target.cgroups.list_subsystems()
for (n,h,g,e) in ssys:
    print '{:10} (hierarchy id: {:d}) has {} cgroups'.format(n, h, g)
# Out:
# 2018-07-10 16:13:36,741 INFO    : root         :         CGroup - Available controllers:
# cpuset     (hierarchy id: 5) has 7 cgroups
# cpu        (hierarchy id: 4) has 1 cgroups
# cpuacct    (hierarchy id: 1) has 2 cgroups
# schedtune  (hierarchy id: 3) has 5 cgroups
# memory     (hierarchy id: 2) has 182 cgroups
# freezer    (hierarchy id: 6) has 1 cgroups
# hugetlb    (hierarchy id: 6) has 1 cgroups

# %%
# Get a reference to the CPUSet controller
cpuset = te.target.cgroups.controller('cpuset')

# %%
# Get the list of current configured CGroups for that controller
cgroups = cpuset.list_all()
print 'Existing CGropups:'
for cg in cgroups:
    print "   ", cg
# Out:
# Existing CGropups:
#     /
#     /LITTLE
#     /system-background
#     /background
#     /foreground
#     /foreground/boost
#     /top-app

# %%
# Create a LITTLE partition and check which tunables we have
cpuset_littles = cpuset.cgroup('/LITTLE')
cpuset_littles.get()
# Out:
# {'cpu_exclusive': '0',
#  'cpus': '0-3',
#  'effective_cpus': '0-3',
#  'effective_mems': '0',
#  'ls': ' /data/local/tmp/devlib-target/cgroups/devlib_cgh5/LITTLE/cpuset.*',
#  'mem_exclusive': '0',
#  'mem_hardwall': '0',
#  'memory_migrate': '0',
#  'memory_pressure': '0',
#  'memory_spread_page': '0',
#  'memory_spread_slab': '0',
#  'mems': '0',
#  'notify_on_release': '0',
#  'sched_load_balance': '1',
#  'sched_relax_domain_level': '-1'}

# %%
# Setup CPUs and MEMORY nodes for the LITTLE partition
cpuset_littles.set(cpus=te.target.bl.littles, mems=0)

# %%
# Dump the configuraiton of each controller
for cgname in cgroups:
    cgroup = cpuset.cgroup(cgname)
    attrs = cgroup.get()
    cpus = attrs['cpus']
    print '{}:{:<15} cpus: {}'.format(cpuset.kind, cgroup.name, cpus)
# Out:
# cpuset:/               cpus: 0-7
# cpuset:/LITTLE         cpus: 0-3
# cpuset:/system-background cpus: 0-3
# cpuset:/background     cpus: 0-1
# cpuset:/foreground     cpus: 0-5
# cpuset:/foreground/boost cpus: 0-5
# cpuset:/top-app        cpus: 0-7

# %%
# Methods exists to move tasks in/out and in between groups
# cpuset_littles.add_task()

# %% [markdown]
# # Sample energy from the target

# %%
# Reset and sample energy counters
# te.emeter.reset()

# Sleep some time
# time.sleep(2)

# Sample energy consumption since last reset
#nrg = te.emeter.sample()
#nrg = json.dumps(te.emeter.sample(), indent=4)
#print "First read: ", nrg

# Sleep some more time
# time.sleep(2)

# Sample again
#nrg = te.emeter.sample()
#nrg = json.dumps(te.emeter.sample(), indent=4)
#print "Second read: ", nrg

# %% [markdown]
# # Configure FTrace for a sepcific experiment

# %%
# Configure a specific set of events to trace
te.ftrace_conf(
    {                                                                                                                                             
         "events" : [                                                                                                                                            
             "cpu_idle",                                                                                                                                         
             "cpu_capacity",
             "cpu_frequency",
             "sched_switch",
         ],                                                                                                                                                      
         "buffsize" : 10240                                                                                                                                      
    }
)
# Out:
# 2018-07-10 16:13:40,570 INFO    : TestEnv      : Enabled tracepoints:
# 2018-07-10 16:13:40,572 INFO    : TestEnv      :    cpu_idle
# 2018-07-10 16:13:40,573 INFO    : TestEnv      :    cpu_capacity
# 2018-07-10 16:13:40,574 INFO    : TestEnv      :    cpu_frequency
# 2018-07-10 16:13:40,576 INFO    : TestEnv      :    sched_switch

# %%
# Start/Stop a FTrace session
te.ftrace.start()
te.target.execute("uname -a")
te.ftrace.stop()

# %%
# Collect and visualize the trace
trace_file = os.path.join(te.res_dir, 'trace.dat')
te.ftrace.get_trace(trace_file)
output = os.popen("DISPLAY=:0.0 kernelshark {}".format(trace_file))
