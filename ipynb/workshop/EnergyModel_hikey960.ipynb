# %% [markdown]
# <center>
# <h1>Energy Model Building Flow - Example 2</h1>
# <h2>for platforms supporting system-level energy meters</h2>
# </center>

# %% [markdown]
# This notebook shows how to build an energy model of a HiKey960 platform running an Android Linux kernel.
#
# It can be used as a reference implementation of an energy model building flow for platforms<br>
# where it's possible to measure the energy consumption at system level, that is either at battery<br>
# level or as close as possible to the clusters.
#
# In this case, it is not enough to isolate the CPUs of the target cluster, but we also have to make<br>
# sure that all tasks (except the essential ones) are **frozen** to avoid affecting battery power<br>
# measurements. This will be achieved by exploiting the cgroup `freezer` controller.

# %% [markdown]
# # Configuration

# %%
import logging
from conf import LisaLogging
LisaLogging.setup()
# Out:
# 2017-08-04 16:29:57,560 INFO    : root         : Using LISA logging configuration:
# 2017-08-04 16:29:57,562 INFO    : root         :   /data/lisa_remote/lisa/logging.conf

# %%
logging.getLogger().setLevel(logging.DEBUG)

# %%
# %matplotlib inline

import devlib
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import trappy

from collections import namedtuple, OrderedDict
from csv import DictWriter
from env import TestEnv
from matplotlib.ticker import FormatStrFormatter, MaxNLocator
from scipy.stats import linregress
from time import sleep
from trappy.plotter.ColorMap import ColorMap

# Support for trace events analysis
from trace import Trace
# Import support for Android devices
from android import Screen, Workload, System
# Out:
# 2017-08-04 16:30:01,054 WARNING : EnergyModel  : Unusual max capacity (1023), overriding capacity_scale

# %%
# Setup a target configuration
my_conf = {
    
    # Target platform and board
    "platform"    : 'android',
    "board"       : 'hikey960',

    "results_dir" : "EnergyModel_SystemEnergy_hikey960",

    # Energy Meters Configuration for BayLibre's ACME Cape
    #"emeter" : {
    #    "instrument" : "aep",
    #    "conf" : {
    #        'resistor_values' : [0.099],
    #        'device_entry'    : '/dev/ttyACM0'
    #    },
    #    "channel_map" : {
    #        "Device0" : "BAT"
    #    }
    #},

    "emeter" : {
        "instrument" : "acme",
        "conf" : {
            'iio-capture' : '/usr/bin/iio-capture',
            'ip_address' : 'baylibre-acme',
        },
        'channel_map' : {
            'Device0' : 0,
         #   'Device1' : 1,
        }
    },

    # Tools required by the experiments
    "tools"   : ['trace-cmd', 'sysbench'],
    "modules" : ['cpufreq', 'cpuidle', 'hotplug', 'cgroups'],
    
    # FTrace events to collect for all the tests configuration which have
    # the "ftrace" flag enabled
    "ftrace"  : {
         "events" : [
            "cpu_frequency",
            "cpu_idle",
            "sched_switch"
         ],
         "buffsize" : 10 * 1024,
    },
}

# %%
# Initialize a test environment using:
# the provided target configuration (my_conf)
te = TestEnv(target_conf=my_conf, force_new=True)
target = te.target
# Out:
# 2017-08-04 16:30:01,719 INFO    : TestEnv      : Using base path: /data/lisa_remote/lisa
# 2017-08-04 16:30:01,726 INFO    : TestEnv      : Loading custom (inline) target configuration
# 2017-08-04 16:30:01,739 INFO    : TestEnv      : External tools using:
# 2017-08-04 16:30:01,745 INFO    : TestEnv      :    ANDROID_HOME: /home/zhifei/zyang/android-sdk-linux
# 2017-08-04 16:30:01,752 INFO    : TestEnv      :    CATAPULT_HOME: /data/lisa_remote/lisa/tools/catapult
# 2017-08-04 16:30:01,754 INFO    : TestEnv      : Devlib modules to load: ['bl', 'cpuidle', 'cpufreq', 'cgroups', 'hotplug']
# 2017-08-04 16:30:01,756 INFO    : TestEnv      : Connecting Android target [DEFAULT]
# 2017-08-04 16:30:01,762 INFO    : TestEnv      : Connection settings:
# 2017-08-04 16:30:01,764 INFO    : TestEnv      :    None
# 2017-08-04 16:30:02,932 INFO    : TestEnv      : Initializing target workdir:
# 2017-08-04 16:30:02,937 INFO    : TestEnv      :    /data/local/tmp/devlib-target
# 2017-08-04 16:30:04,046 DEBUG   : CGroups      : Available hierarchies: {0: ['blkio', 'devices', 'freezer', 'hugetlb', 'debug'], 1: ['cpuacct'], 2: ['memory'], 3: ['schedtune'], 4: ['cpu'], 5: ['cpuset']}
# 2017-08-04 16:30:04,051 INFO    : CGroups      : Available controllers:
# 2017-08-04 16:30:04,053 DEBUG   : CGroup.cpuset : Initialized [cpuset, 5, ['cpuset']]
# 2017-08-04 16:30:04,289 DEBUG   : CGroup.cpuset : Controller cpuset mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh5 (noprefix=True)
# 2017-08-04 16:30:04,293 DEBUG   : cgroups.cpuset : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh5
# 2017-08-04 16:30:04,353 INFO    : CGroups      :   cpuset       : /data/local/tmp/devlib-target/cgroups/devlib_cgh5
# 2017-08-04 16:30:04,355 DEBUG   : CGroup.cpu   : Initialized [cpu, 4, ['cpu']]
# 2017-08-04 16:30:04,590 DEBUG   : CGroup.cpu   : Controller cpu mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh4 (noprefix=False)
# 2017-08-04 16:30:04,594 DEBUG   : cgroups.cpu  : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh4
# 2017-08-04 16:30:04,654 INFO    : CGroups      :   cpu          : /data/local/tmp/devlib-target/cgroups/devlib_cgh4
# 2017-08-04 16:30:04,656 DEBUG   : CGroup.cpuacct : Initialized [cpuacct, 1, ['cpuacct']]
# 2017-08-04 16:30:04,887 DEBUG   : CGroup.cpuacct : Controller cpuacct mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh1 (noprefix=False)
# 2017-08-04 16:30:04,893 DEBUG   : cgroups.cpuacct : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh1
# 2017-08-04 16:30:04,947 INFO    : CGroups      :   cpuacct      : /data/local/tmp/devlib-target/cgroups/devlib_cgh1
# 2017-08-04 16:30:04,949 DEBUG   : CGroup.schedtune : Initialized [schedtune, 3, ['schedtune']]
# 2017-08-04 16:30:05,165 DEBUG   : CGroup.schedtune : Controller schedtune mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh3 (noprefix=False)
# 2017-08-04 16:30:05,168 DEBUG   : cgroups.schedtune : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh3
# 2017-08-04 16:30:05,224 INFO    : CGroups      :   schedtune    : /data/local/tmp/devlib-target/cgroups/devlib_cgh3
# 2017-08-04 16:30:05,226 DEBUG   : CGroup.blkio : Initialized [blkio, 0, ['blkio', 'devices', 'freezer', 'hugetlb', 'debug']]
# 2017-08-04 16:30:05,449 DEBUG   : CGroup.blkio : Controller blkio mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh0 (noprefix=False)
# 2017-08-04 16:30:05,450 DEBUG   : cgroups.blkio : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:05,518 INFO    : CGroups      :   blkio        : /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:05,521 DEBUG   : CGroup.memory : Initialized [memory, 2, ['memory']]
# 2017-08-04 16:30:05,764 DEBUG   : CGroup.memory : Controller memory mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh2 (noprefix=False)
# 2017-08-04 16:30:05,769 DEBUG   : cgroups.memory : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh2
# 2017-08-04 16:30:05,827 INFO    : CGroups      :   memory       : /data/local/tmp/devlib-target/cgroups/devlib_cgh2
# 2017-08-04 16:30:05,833 DEBUG   : CGroup.devices : Initialized [devices, 0, ['blkio', 'devices', 'freezer', 'hugetlb', 'debug']]
# 2017-08-04 16:30:05,957 DEBUG   : CGroup.devices : Controller devices mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh0 (noprefix=False)
# 2017-08-04 16:30:05,973 DEBUG   : cgroups.devices : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,033 INFO    : CGroups      :   devices      : /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,035 DEBUG   : CGroup.freezer : Initialized [freezer, 0, ['blkio', 'devices', 'freezer', 'hugetlb', 'debug']]
# 2017-08-04 16:30:06,136 DEBUG   : CGroup.freezer : Controller freezer mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh0 (noprefix=False)
# 2017-08-04 16:30:06,138 DEBUG   : cgroups.freezer : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,204 INFO    : CGroups      :   freezer      : /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,206 DEBUG   : CGroup.hugetlb : Initialized [hugetlb, 0, ['blkio', 'devices', 'freezer', 'hugetlb', 'debug']]
# 2017-08-04 16:30:06,308 DEBUG   : CGroup.hugetlb : Controller hugetlb mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh0 (noprefix=False)
# 2017-08-04 16:30:06,310 DEBUG   : cgroups.hugetlb : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,370 INFO    : CGroups      :   hugetlb      : /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,373 DEBUG   : CGroup.debug : Initialized [debug, 0, ['blkio', 'devices', 'freezer', 'hugetlb', 'debug']]
# 2017-08-04 16:30:06,491 DEBUG   : CGroup.debug : Controller debug mounted under: /data/local/tmp/devlib-target/cgroups/devlib_cgh0 (noprefix=False)
# 2017-08-04 16:30:06,493 DEBUG   : cgroups.debug : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:06,563 INFO    : CGroups      :   debug        : /data/local/tmp/devlib-target/cgroups/devlib_cgh0
# 2017-08-04 16:30:07,364 INFO    : TestEnv      : Topology:
# 2017-08-04 16:30:07,368 INFO    : TestEnv      :    [[0, 1, 2, 3], [4, 5, 6, 7]]
# 2017-08-04 16:30:07,569 INFO    : TestEnv      : Loading default EM:
# 2017-08-04 16:30:07,574 INFO    : TestEnv      :    /data/lisa_remote/lisa/libs/utils/platforms/hikey960.json
# 2017-08-04 16:30:07,582 DEBUG   : JsonConf     : loading JSON...
# 2017-08-04 16:30:07,584 DEBUG   : JsonConf     : Loaded JSON configuration:
# 2017-08-04 16:30:07,590 DEBUG   : JsonConf     :    {u'nrg_model': {u'big': {u'cluster': {u'nrg_max': 118}, u'cpu': {u'cap_max': 1024, u'nrg_max': 1715}}, u'little': {u'cluster': {u'nrg_max': 70}, u'cpu': {u'cap_max': 870, u'nrg_max': 1210}}}, u'board': {u'big_core': u'A73_1', u'cores': [u'A53_0', u'A53_0', u'A53_0', u'A53_0', u'A73_1', u'A73_1', u'A73_1', u'A73_1'], u'modules': [u'bl', u'cpufreq', u'cpuidle']}}
# 2017-08-04 16:30:08,122 INFO    : TestEnv      : Enabled tracepoints:
# 2017-08-04 16:30:08,132 INFO    : TestEnv      :    cpu_frequency
# 2017-08-04 16:30:08,137 INFO    : TestEnv      :    cpu_idle
# 2017-08-04 16:30:08,138 INFO    : TestEnv      :    sched_switch
# 2017-08-04 16:30:08,141 WARNING : TestEnv      : Wipe previous contents of the results folder:
# 2017-08-04 16:30:08,144 WARNING : TestEnv      :    /data/lisa_remote/lisa/results/EnergyModel_SystemEnergy_hikey960
# 2017-08-04 16:30:08,149 DEBUG   : EnergyMeter  : using user-defined configuration
# 2017-08-04 16:30:08,153 INFO    : EnergyMeter  : ACME configuration:
# 2017-08-04 16:30:08,154 INFO    : EnergyMeter  :     binary: /usr/bin/iio-capture
# 2017-08-04 16:30:08,156 INFO    : EnergyMeter  :     device: baylibre-acme
# 2017-08-04 16:30:08,159 INFO    : EnergyMeter  :   channels:
# 2017-08-04 16:30:08,163 INFO    : EnergyMeter  :      Device0 (iio:device0)
# 2017-08-04 16:30:08,190 DEBUG   : EnergyMeter  : Results dir: /data/lisa_remote/lisa/results/EnergyModel_SystemEnergy_hikey960
# 2017-08-04 16:30:08,196 INFO    : TestEnv      : Set results folder to:
# 2017-08-04 16:30:08,203 INFO    : TestEnv      :    /data/lisa_remote/lisa/results/EnergyModel_SystemEnergy_hikey960
# 2017-08-04 16:30:08,213 INFO    : TestEnv      : Experiment results available also in:
# 2017-08-04 16:30:08,214 INFO    : TestEnv      :    /data/lisa_remote/lisa/results_latest

# %% [markdown]
# ## Critical tasks declaration

# %% [markdown]
# Energy measured of a cluster at system-level is affected by noise due the other clusters running in the system. To limit effect of this noise we exploit the `freezer cpuset` controller to freeze the tasks already running in the system. However, we need to be careful not to freeze those tasks that allow us to communicate with the target.
#
# Hence, we define here-below a list of tasks called *CRITICAL* that must not be frozen.

# %%
# Lists of critical tasks for each platform
CRITICAL_TASKS = {
    'linux': ["init", "sh"],
    'android': ["/system/bin/sh", "adbd", "/init"]
    }

# %% [markdown]
# ## Energy Model Parameters (CPUs, OPPs and Idle States)

# %%
# The EM reports capacity and energy consumption for each frequency domain.
# The frequency domains to be considered by the following EM building flow
# are described by the parameters of this named tuple
ClusterDescription = namedtuple('ClusterDescription',
                                ['name', 'emeter_ch', 'core_name',
                                 'cpus', 'freqs', 'idle_states'])

# %% [markdown]
# Being Hikey a SMP platform we can limit the scope of the experiment to one cluster only and then replicate the code by hand.

# %%
clusters = [
    ClusterDescription(
        # Name of the cluster
        name = "PD_0",
        # Name of the energy meter channel as specified in the target configuration
        emeter_ch = "Device0",
        # Name of the cores in the cluster
        core_name = "A53_PD_0",
        # List of cores in the cluster
        cpus = [0, 1, 2, 3],
        # List of frequencies available in the cluster
        freqs = [533000, 999000, 1402000, 1709000, 1844000],
        # List of idle states available in the cluster
        idle_states = range(len(target.cpuidle.get_states()))
    ),
    
     ClusterDescription("PD_1",
                        "Device0",
                        "A73_PD_1",
                        [4, 5, 6, 7],
                        [903000, 1421000, 1805000, 2112000, 2362000],
                        range(len(target.cpuidle.get_states()))
     ),
]

# %%
clusters
# Out:
# [ClusterDescription(name='PD_0', emeter_ch='Device0', core_name='A53_PD_0', cpus=[0, 1, 2, 3], freqs=[533000, 999000, 1402000, 1709000, 1844000], idle_states=[0, 1, 2]),
#  ClusterDescription(name='PD_1', emeter_ch='Device0', core_name='A73_PD_1', cpus=[4, 5, 6, 7], freqs=[903000, 1421000, 1805000, 2112000, 2362000], idle_states=[0, 1, 2])]

# %%
# Mapping between cluster names and cluster IDs
cluster_ids = OrderedDict([
        (0, 'PD_0'),
         (1, 'PD_1')
    ])

# %% [markdown]
# ## Benchmark example

# %%
class Sysbench(object):
    """
    Sysbench benchmark class.
    
    :param duration: maximum workload duration in seconds
    :type duration: int
    """
    sysbench_path = "/data/local/tmp/bin/sysbench"
    
    def __init__(self, target, duration):
        self.target = target
        self.duration = duration

    def run(self, cgroup, threads):
        """
        Run benchmark using the specified number of 'threads'
        to be executed under the specified 'cgroup'.
        
        :param cgroup: cgroup where to run the benchmark on
        :type cgroup: str
        
        :param threads: number of threads to spawn
        :type threads: int
        
        :returns: float - performance score
        """
        bench_out = self.target.cgroups.run_into(
            cgroup,
            "{} --test=cpu --num-threads={} --max-time={} run"
            .format(self.sysbench_path, threads, self.duration)
        )
        match = re.search(r'(total number of events:\s*)([\d.]*)', bench_out)
        return float(match.group(2))

# %% [markdown]
# # Utility Functions

# %%
def linfit(x, y):
    slope, intercept, r, p, stderr = linregress(x, y)
    return slope, intercept

# %% [markdown]
# # Energy Model Building

# %% [markdown]
# ## Active States Profiling

# %%
def compute_power_perf(clusters, loop_cnt, benchmark, bkp_file='pstates.csv'):
    """
    Perform P-States profiling on each input cluster.
    
    This method requires a `benchmark` object with the following
    characteristics:
        
        - duration, attribute that tells the workload duration in seconds
        - run(cgroup, threads), run the benchmark into the specified 'cgroup',
                                spawning the specified number of 'threads',
                                and return a performance score of their execution.
                                
    Data will be saved into a CSV file at each iteration such that, if something
    goes wrong, the user can restart the experiment considering only idle_states
    that had not yet been profiled.
    
    :param clusters: list of clusters to profile
    :type clusters: list(namedtuple(ClusterDescription))
    
    :param loop_cnt: number of iterations for each experiment
    :type loop_cnt: int
    
    :param benchmark: benchmark object
    :type benchmark: int
    
    :param bkp_file: CSV file name
    :type bkp_file: str
    """

    # Make sure all CPUs are online
    target.hotplug.online_all()

    # Set cpufreq governor to userpace to allow manual frequency scaling
    target.cpufreq.set_all_governors('userspace')
    
    with open(bkp_file, 'w') as csvfile:
        writer = DictWriter(csvfile,
                            fieldnames=['cluster', 'cpus', 'freq',
                                        'perf', 'energy', 'power'])

        # Freeze all userspace tasks
        target.cgroups.freeze(exclude=CRITICAL_TASKS['android'])

        # A) For each cluster (i.e. frequency domain) to profile...
        power_perf = []
        for cl in clusters:
            target_cg, _ = target.cgroups.isolate(cl.cpus)

            # P-States profiling requires to plug in CPUs one at the time
            for cpu in cl.cpus:
                target.hotplug.offline(cpu)

            # B) For each additional cluster's plugged in CPU...
            on_cpus = []
            for cnt, cpu in enumerate(cl.cpus):
                
                # Hotplug ON one more CPU
                target.hotplug.online(cpu)
                on_cpus.append(cpu)
                
                # Ensure online CPUs are part of the target cgroup
                # (in case hotplug OFF removes it)
                target_cg.set(cpus=on_cpus)
                cl_cpus = set(target.list_online_cpus()).intersection(set(cl.cpus))
                logging.info('Cluster {:8} (Online CPUs : {})'\
                              .format(cl.name, list(cl_cpus)))

                # C) For each OPP supported by the current cluster
                for freq in cl.freqs:

                    # Set frequency to freq for current CPU
                    target.cpufreq.set_frequency(cpu, freq)

                    # Run the benchmark for the specified number of iterations each time
                    # collecting a sample of energy consumption and reported performance
                    energy = 0.0
                    perf = 0.0
                    for i in xrange(loop_cnt):
                        te.emeter.reset()
                        # Run benchmark into the LISA_EM_TARGET cgroup
                        perf += benchmark.run(target_cg.name, cnt + 1)
                        nrg = te.emeter.report(te.res_dir).channels
                        energy += float(nrg[cl.emeter_ch])
                        #sleep(1)
                        sleep(5)

                    # Compute average energy and performance for the current number of
                    # active CPUs all running at the current OPP
                    perf = perf / loop_cnt
                    energy = energy / loop_cnt
                    power = energy / benchmark.duration

                    # Keep track of this new P-State profiling point
                    new_row = {'cluster': cl.name,
                               'cpus': cnt + 1,
                               'freq': freq,
                               'perf': perf,
                               'energy' : energy,
                               'power': power}
                    power_perf.append(new_row)

                    # Save data in a CSV file
                    writer.writerow(new_row)
                    
                # C) profile next P-State

            # B) add one more CPU (for the current frequency domain)

        # A) Profile next cluster (i.e. frequency domain)
                    
        # Thaw all frozen tasks
        target.cgroups.freeze(thaw=True)

        target.hotplug.online_all()

        power_perf_df = pd.DataFrame(power_perf)
    return power_perf_df.set_index(['cluster', 'freq', 'cpus']).sort_index(level='cluster')

# %%
sysbench = Sysbench(target, 10)
loop_cnt = 3

power_perf_df = compute_power_perf(clusters, loop_cnt, sysbench)
# Out:
# 2017-08-04 16:30:26,261 DEBUG   : cgroups.freezer : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh0/DEVLIB_FREEZER
# 2017-08-04 16:30:26,334 DEBUG   : root         : Moving all tasks into /DEVLIB_FREEZER
# 2017-08-04 16:30:26,338 DEBUG   : root         :    using grep filter: -e /system/bin/sh -e adbd -e /init
# 2017-08-04 16:30:26,340 DEBUG   : root         :    excluding tasks which name matches:
# 2017-08-04 16:30:26,344 DEBUG   : root         :    /system/bin/sh, adbd, /init
# 2017-08-04 16:30:26,884 DEBUG   : cgroups.freezer : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh0/DEVLIB_FREEZER/freezer.state] to: FROZEN"
# 2017-08-04 16:30:26,993 DEBUG   : cgroups.cpuset : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX
# 2017-08-04 16:30:27,058 DEBUG   : cgroups.cpuset : Creating cgroup /data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_ISOL
# 2017-08-04 16:30:27,123 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 4-7"
# 2017-08-04 16:30:27,260 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/mems] to: 0"
# 2017-08-04 16:30:27,389 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_ISOL/cpus] to: 0-3"
# 2017-08-04 16:30:27,532 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_ISOL/mems] to: 0"
# 2017-08-04 16:30:27,662 DEBUG   : root         : Moving all tasks into /DEVLIB_SBOX
# 2017-08-04 16:30:27,668 DEBUG   : root         :    using grep filter:
# 2017-08-04 16:30:28,998 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 0"
# 2017-08-04 16:30:29,410 INFO    : root         : Cluster PD_0     (Online CPUs : [0])
# 2017-08-04 16:30:30,862 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:30:44,323 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:30:44,328 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12205.00 energy=19346.05 pmax=2000.00 pavg=1723.01 pmin=1225.00 cmax=162.00 cmin=100.00 ]
# 2017-08-04 16:30:44,332 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:30:44,334 DEBUG   : EnergyMeter  : {'cmin': 100.0, 'energy': 19346.05, 'pavg': 1723.01, 'pmin': 1225.0, 'vmax': 12205.0, 'cmax': 162.0, 'pmax': 2000.0}
# 2017-08-04 16:30:50,380 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:31:03,825 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:31:03,830 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=14301.54 pmax=1925.00 pavg=1273.73 pmin=1150.00 cmax=158.00 cmin=94.00 ]
# 2017-08-04 16:31:03,836 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:31:03,840 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 14301.54, 'pavg': 1273.73, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 158.0, 'pmax': 1925.0}
# 2017-08-04 16:31:09,893 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:31:23,335 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:31:23,341 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=14496.49 pmax=2075.00 pavg=1291.09 pmin=1150.00 cmax=168.00 cmin=94.00 ]
# 2017-08-04 16:31:23,342 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:31:23,343 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 14496.49, 'pavg': 1291.09, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 168.0, 'pmax': 2075.0}
# 2017-08-04 16:31:29,759 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:31:42,682 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:31:42,683 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12205.00 energy=7263.38 pmax=1725.00 pavg=1293.79 pmin=1225.00 cmax=141.00 cmin=101.00 ]
# 2017-08-04 16:31:42,684 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:31:42,684 DEBUG   : EnergyMeter  : {'cmin': 101.0, 'energy': 7263.38, 'pavg': 1293.79, 'pmin': 1225.0, 'vmax': 12205.0, 'cmax': 141.0, 'pmax': 1725.0}
# 2017-08-04 16:31:48,753 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:32:01,093 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:32:01,094 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=13169.08 pmax=2000.00 pavg=1303.19 pmin=1150.00 cmax=165.00 cmin=94.00 ]
# 2017-08-04 16:32:01,095 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:32:01,095 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 13169.08, 'pavg': 1303.19, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 165.0, 'pmax': 2000.0}
# 2017-08-04 16:32:07,132 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:32:19,476 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:32:19,478 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12205.00 energy=14364.91 pmax=2025.00 pavg=1421.53 pmin=1225.00 cmax=167.00 cmin=101.00 ]
# 2017-08-04 16:32:19,479 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:32:19,479 DEBUG   : EnergyMeter  : {'cmin': 101.0, 'energy': 14364.91, 'pavg': 1421.53, 'pmin': 1225.0, 'vmax': 12205.0, 'cmax': 167.0, 'pmax': 2025.0}
# 2017-08-04 16:32:25,760 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:32:38,095 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:32:38,104 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=13832.89 pmax=2150.00 pavg=1368.88 pmin=1150.00 cmax=175.00 cmin=94.00 ]
# 2017-08-04 16:32:38,115 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:32:38,118 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 13832.89, 'pavg': 1368.88, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 175.0, 'pmax': 2150.0}
# 2017-08-04 16:32:44,196 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:32:56,564 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:32:56,577 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=13751.75 pmax=2150.00 pavg=1360.85 pmin=1150.00 cmax=177.00 cmin=94.00 ]
# 2017-08-04 16:32:56,582 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:32:56,589 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 13751.75, 'pavg': 1360.85, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 177.0, 'pmax': 2150.0}
# 2017-08-04 16:33:02,668 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:33:15,035 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:33:15,044 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=13760.75 pmax=2050.00 pavg=1361.74 pmin=1150.00 cmax=168.00 cmin=94.00 ]
# 2017-08-04 16:33:15,055 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:33:15,057 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 13760.75, 'pavg': 1361.74, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 168.0, 'pmax': 2050.0}
# 2017-08-04 16:33:21,330 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:33:33,667 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:33:33,668 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=16757.89 pmax=2225.00 pavg=1658.33 pmin=1150.00 cmax=182.00 cmin=94.00 ]
# 2017-08-04 16:33:33,669 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:33:33,670 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 16757.89, 'pavg': 1658.33, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 182.0, 'pmax': 2225.0}
# 2017-08-04 16:33:39,731 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:33:52,069 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:33:52,081 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=16655.48 pmax=2225.00 pavg=1648.20 pmin=1150.00 cmax=182.00 cmin=94.00 ]
# 2017-08-04 16:33:52,093 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:33:52,093 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 16655.48, 'pavg': 1648.2, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 182.0, 'pmax': 2225.0}
# 2017-08-04 16:33:58,165 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:34:10,505 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:34:10,521 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=16701.10 pmax=2225.00 pavg=1652.71 pmin=1150.00 cmax=182.00 cmin=95.00 ]
# 2017-08-04 16:34:10,529 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:34:10,535 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 16701.1, 'pavg': 1652.71, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 182.0, 'pmax': 2225.0}
# 2017-08-04 16:34:16,805 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:34:29,156 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:34:29,165 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=17406.58 pmax=2400.00 pavg=1722.53 pmin=1150.00 cmax=196.00 cmin=94.00 ]
# 2017-08-04 16:34:29,175 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:34:29,177 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 17406.58, 'pavg': 1722.53, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 196.0, 'pmax': 2400.0}
# 2017-08-04 16:34:35,246 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:34:47,632 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:34:47,641 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=17313.38 pmax=2325.00 pavg=1713.30 pmin=1150.00 cmax=190.00 cmin=95.00 ]
# 2017-08-04 16:34:47,648 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:34:47,655 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 17313.38, 'pavg': 1713.3, 'pmin': 1150.0, 'vmax': 12206.25, 'cmax': 190.0, 'pmax': 2325.0}
# 2017-08-04 16:34:53,700 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:35:06,049 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:35:06,056 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=17380.04 pmax=2325.00 pavg=1719.90 pmin=1150.00 cmax=191.00 cmin=95.00 ]
# 2017-08-04 16:35:06,059 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:35:06,062 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 17380.04, 'pavg': 1719.9, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 191.0, 'pmax': 2325.0}
# 2017-08-04 16:35:11,410 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 0-1"
# 2017-08-04 16:35:11,650 INFO    : root         : Cluster PD_0     (Online CPUs : [0, 1])
# 2017-08-04 16:35:12,919 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:35:25,307 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:35:25,317 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=13346.71 pmax=2050.00 pavg=1320.77 pmin=1150.00 cmax=169.00 cmin=95.00 ]
# 2017-08-04 16:35:25,325 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:35:25,326 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 13346.71, 'pavg': 1320.77, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 169.0, 'pmax': 2050.0}
# 2017-08-04 16:35:31,407 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:35:44,877 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:35:44,893 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14641.01 pmax=2125.00 pavg=1303.96 pmin=1150.00 cmax=173.00 cmin=94.00 ]
# 2017-08-04 16:35:44,895 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:35:44,897 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 14641.01, 'pavg': 1303.96, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 173.0, 'pmax': 2125.0}
# 2017-08-04 16:35:50,968 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:36:04,426 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:36:04,427 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14611.62 pmax=1975.00 pavg=1301.35 pmin=1150.00 cmax=161.00 cmin=94.00 ]
# 2017-08-04 16:36:04,428 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:36:04,428 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 14611.62, 'pavg': 1301.35, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 161.0, 'pmax': 1975.0}
# 2017-08-04 16:36:10,815 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:36:23,157 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:36:23,167 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=13976.32 pmax=2100.00 pavg=1383.07 pmin=1200.00 cmax=171.00 cmin=96.00 ]
# 2017-08-04 16:36:23,173 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:36:23,177 DEBUG   : EnergyMeter  : {'cmin': 96.0, 'energy': 13976.32, 'pavg': 1383.07, 'pmin': 1200.0, 'vmax': 12207.5, 'cmax': 171.0, 'pmax': 2100.0}
# 2017-08-04 16:36:29,226 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:36:41,664 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:36:41,677 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14033.55 pmax=1975.00 pavg=1388.74 pmin=1150.00 cmax=160.00 cmin=94.00 ]
# 2017-08-04 16:36:41,684 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:36:41,686 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 14033.55, 'pavg': 1388.74, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 160.0, 'pmax': 1975.0}
# 2017-08-04 16:36:47,739 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:37:00,079 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:37:00,080 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=13894.08 pmax=2050.00 pavg=1374.93 pmin=1150.00 cmax=169.00 cmin=94.00 ]
# 2017-08-04 16:37:00,081 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:37:00,095 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 13894.08, 'pavg': 1374.93, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 169.0, 'pmax': 2050.0}
# 2017-08-04 16:37:06,339 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:37:18,699 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:37:18,709 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14900.66 pmax=2175.00 pavg=1474.54 pmin=1150.00 cmax=178.00 cmin=94.00 ]
# 2017-08-04 16:37:18,719 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:37:18,722 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 14900.66, 'pavg': 1474.54, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 178.0, 'pmax': 2175.0}
# 2017-08-04 16:37:24,769 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:37:37,101 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:37:37,111 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=15023.46 pmax=2200.00 pavg=1486.70 pmin=1150.00 cmax=179.00 cmin=94.00 ]
# 2017-08-04 16:37:37,119 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:37:37,125 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 15023.46, 'pavg': 1486.7, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 179.0, 'pmax': 2200.0}
# 2017-08-04 16:37:43,177 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:37:55,511 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:37:55,512 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14957.46 pmax=2175.00 pavg=1480.16 pmin=1150.00 cmax=177.00 cmin=95.00 ]
# 2017-08-04 16:37:55,513 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:37:55,514 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 14957.46, 'pavg': 1480.16, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 16:38:01,780 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:38:14,146 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:38:14,155 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=18411.40 pmax=2400.00 pavg=1821.96 pmin=1150.00 cmax=196.00 cmin=94.00 ]
# 2017-08-04 16:38:14,162 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:38:14,164 DEBUG   : EnergyMeter  : {'cmin': 94.0, 'energy': 18411.4, 'pavg': 1821.96, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 196.0, 'pmax': 2400.0}
# 2017-08-04 16:38:20,234 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:38:32,590 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:38:32,602 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=18331.80 pmax=2475.00 pavg=1814.08 pmin=1150.00 cmax=202.00 cmin=95.00 ]
# 2017-08-04 16:38:32,609 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:38:32,614 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 18331.8, 'pavg': 1814.08, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 202.0, 'pmax': 2475.0}
# 2017-08-04 16:38:38,694 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:38:51,049 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:38:51,060 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=18295.18 pmax=2400.00 pavg=1810.46 pmin=1150.00 cmax=197.00 cmin=95.00 ]
# 2017-08-04 16:38:51,082 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:38:51,084 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 18295.18, 'pavg': 1810.46, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 197.0, 'pmax': 2400.0}
# 2017-08-04 16:38:57,326 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:39:09,669 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:39:09,677 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=19782.89 pmax=2575.00 pavg=1957.68 pmin=1150.00 cmax=211.00 cmin=95.00 ]
# 2017-08-04 16:39:09,687 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:39:09,689 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 19782.89, 'pavg': 1957.68, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 211.0, 'pmax': 2575.0}
# 2017-08-04 16:39:15,768 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:39:28,113 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:39:28,117 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=19675.88 pmax=2500.00 pavg=1947.09 pmin=1150.00 cmax=205.00 cmin=95.00 ]
# 2017-08-04 16:39:28,130 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:39:28,134 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 19675.88, 'pavg': 1947.09, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 205.0, 'pmax': 2500.0}
# 2017-08-04 16:39:34,219 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:39:46,583 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:39:46,592 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=19675.88 pmax=2675.00 pavg=1947.09 pmin=1150.00 cmax=219.00 cmin=95.00 ]
# 2017-08-04 16:39:46,603 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:39:46,605 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 19675.88, 'pavg': 1947.09, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 219.0, 'pmax': 2675.0}
# 2017-08-04 16:39:51,926 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 0-2"
# 2017-08-04 16:39:52,198 INFO    : root         : Cluster PD_0     (Online CPUs : [0, 1, 2])
# 2017-08-04 16:39:53,468 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:40:05,812 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:40:05,821 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12206.25 energy=14050.88 pmax=2025.00 pavg=1390.45 pmin=1175.00 cmax=166.00 cmin=96.00 ]
# 2017-08-04 16:40:05,829 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:40:05,837 DEBUG   : EnergyMeter  : {'cmin': 96.0, 'energy': 14050.88, 'pavg': 1390.45, 'pmin': 1175.0, 'vmax': 12206.25, 'cmax': 166.0, 'pmax': 2025.0}
# 2017-08-04 16:40:11,899 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:40:25,360 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:40:25,362 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=15113.16 pmax=2075.00 pavg=1346.02 pmin=1150.00 cmax=170.00 cmin=95.00 ]
# 2017-08-04 16:40:25,364 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:40:25,369 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 15113.16, 'pavg': 1346.02, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 170.0, 'pmax': 2075.0}
# 2017-08-04 16:40:31,431 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:40:43,784 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:40:43,787 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=15060.75 pmax=2050.00 pavg=1348.72 pmin=1150.00 cmax=168.00 cmin=95.00 ]
# 2017-08-04 16:40:43,800 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:40:43,803 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 15060.75, 'pavg': 1348.72, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 168.0, 'pmax': 2050.0}
# 2017-08-04 16:40:50,183 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:41:02,523 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:41:02,533 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14626.32 pmax=2100.00 pavg=1447.40 pmin=1150.00 cmax=172.00 cmin=95.00 ]
# 2017-08-04 16:41:02,540 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:41:02,548 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 14626.32, 'pavg': 1447.4, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 172.0, 'pmax': 2100.0}
# 2017-08-04 16:41:08,602 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:41:20,949 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:41:20,959 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14484.87 pmax=2275.00 pavg=1433.40 pmin=1150.00 cmax=187.00 cmin=95.00 ]
# 2017-08-04 16:41:20,966 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:41:20,973 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 14484.87, 'pavg': 1433.4, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 187.0, 'pmax': 2275.0}
# 2017-08-04 16:41:27,042 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:41:39,428 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:41:39,432 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=14498.90 pmax=2100.00 pavg=1434.79 pmin=1150.00 cmax=173.00 cmin=95.00 ]
# 2017-08-04 16:41:39,435 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:41:39,442 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 14498.9, 'pavg': 1434.79, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 173.0, 'pmax': 2100.0}
# 2017-08-04 16:41:45,737 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:41:58,135 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:41:58,141 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=16161.84 pmax=2175.00 pavg=1599.35 pmin=1150.00 cmax=179.00 cmin=95.00 ]
# 2017-08-04 16:41:58,148 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:41:58,152 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 16161.84, 'pavg': 1599.35, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 179.0, 'pmax': 2175.0}
# 2017-08-04 16:42:04,204 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:42:16,602 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:42:16,604 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=16207.02 pmax=2275.00 pavg=1603.82 pmin=1150.00 cmax=187.00 cmin=95.00 ]
# 2017-08-04 16:42:16,612 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:42:16,613 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 16207.02, 'pavg': 1603.82, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 187.0, 'pmax': 2275.0}
# 2017-08-04 16:42:22,695 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:42:35,048 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:42:35,059 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=20845.61 pmax=2375.00 pavg=2062.85 pmin=1675.00 cmax=195.00 cmin=138.00 ]
# 2017-08-04 16:42:35,065 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:42:35,073 DEBUG   : EnergyMeter  : {'cmin': 138.0, 'energy': 20845.61, 'pavg': 2062.85, 'pmin': 1675.0, 'vmax': 12198.75, 'cmax': 195.0, 'pmax': 2375.0}
# 2017-08-04 16:42:41,341 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:42:53,683 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:42:53,693 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=22912.94 pmax=2500.00 pavg=2267.43 pmin=1675.00 cmax=204.00 cmin=139.00 ]
# 2017-08-04 16:42:53,702 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:42:53,706 DEBUG   : EnergyMeter  : {'cmin': 139.0, 'energy': 22912.94, 'pavg': 2267.43, 'pmin': 1675.0, 'vmax': 12198.75, 'cmax': 204.0, 'pmax': 2500.0}
# 2017-08-04 16:42:59,811 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:43:12,154 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:43:12,166 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=23025.22 pmax=2475.00 pavg=2278.54 pmin=1700.00 cmax=203.00 cmin=140.00 ]
# 2017-08-04 16:43:12,175 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:43:12,178 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 23025.22, 'pavg': 2278.54, 'pmin': 1700.0, 'vmax': 12197.5, 'cmax': 203.0, 'pmax': 2475.0}
# 2017-08-04 16:43:18,252 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:43:30,627 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:43:30,628 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=23096.49 pmax=2500.00 pavg=2285.59 pmin=1700.00 cmax=204.00 cmin=140.00 ]
# 2017-08-04 16:43:30,628 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:43:30,629 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 23096.49, 'pavg': 2285.59, 'pmin': 1700.0, 'vmax': 12198.75, 'cmax': 204.0, 'pmax': 2500.0}
# 2017-08-04 16:43:36,858 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:43:48,114 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:43:48,121 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=22127.41 pmax=2700.00 pavg=2463.40 pmin=1750.00 cmax=222.00 cmin=143.00 ]
# 2017-08-04 16:43:48,129 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:43:48,131 DEBUG   : EnergyMeter  : {'cmin': 143.0, 'energy': 22127.41, 'pavg': 2463.4, 'pmin': 1750.0, 'vmax': 12197.5, 'cmax': 222.0, 'pmax': 2700.0}
# 2017-08-04 16:43:54,185 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:44:05,420 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:44:05,435 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=22168.64 pmax=2775.00 pavg=2467.99 pmin=1725.00 cmax=228.00 cmin=140.00 ]
# 2017-08-04 16:44:05,439 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:44:05,445 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 22168.64, 'pavg': 2467.99, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 228.0, 'pmax': 2775.0}
# 2017-08-04 16:44:11,515 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:44:22,740 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:44:22,749 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=22154.17 pmax=2700.00 pavg=2466.38 pmin=1725.00 cmax=220.00 cmin=141.00 ]
# 2017-08-04 16:44:22,758 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:44:22,761 DEBUG   : EnergyMeter  : {'cmin': 141.0, 'energy': 22154.17, 'pavg': 2466.38, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 220.0, 'pmax': 2700.0}
# 2017-08-04 16:44:28,077 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 0-3"
# 2017-08-04 16:44:28,331 INFO    : root         : Cluster PD_0     (Online CPUs : [0, 1, 2, 3])
# 2017-08-04 16:44:29,628 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:44:43,080 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:44:43,087 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=20952.85 pmax=2125.00 pavg=1866.11 pmin=1725.00 cmax=174.00 cmin=142.00 ]
# 2017-08-04 16:44:43,094 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:44:43,101 DEBUG   : EnergyMeter  : {'cmin': 142.0, 'energy': 20952.85, 'pavg': 1866.11, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 174.0, 'pmax': 2125.0}
# 2017-08-04 16:44:49,148 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:45:02,602 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:45:02,605 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=20899.34 pmax=2075.00 pavg=1861.35 pmin=1725.00 cmax=170.00 cmin=140.00 ]
# 2017-08-04 16:45:02,618 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:45:02,621 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 20899.34, 'pavg': 1861.35, 'pmin': 1725.0, 'vmax': 12198.75, 'cmax': 170.0, 'pmax': 2075.0}
# 2017-08-04 16:45:08,689 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:45:22,151 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:45:22,162 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=20894.52 pmax=2125.00 pavg=1860.92 pmin=1700.00 cmax=175.00 cmin=140.00 ]
# 2017-08-04 16:45:22,170 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:45:22,172 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 20894.52, 'pavg': 1860.92, 'pmin': 1700.0, 'vmax': 12198.75, 'cmax': 175.0, 'pmax': 2125.0}
# 2017-08-04 16:45:28,549 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:45:40,901 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:45:40,912 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=20204.39 pmax=2175.00 pavg=1999.39 pmin=1725.00 cmax=180.00 cmin=140.00 ]
# 2017-08-04 16:45:40,920 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:45:40,929 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 20204.39, 'pavg': 1999.39, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 180.0, 'pmax': 2175.0}
# 2017-08-04 16:45:47,024 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:45:59,377 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:45:59,389 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=20227.19 pmax=2275.00 pavg=2001.65 pmin=1725.00 cmax=187.00 cmin=142.00 ]
# 2017-08-04 16:45:59,393 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:45:59,398 DEBUG   : EnergyMeter  : {'cmin': 142.0, 'energy': 20227.19, 'pavg': 2001.65, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 187.0, 'pmax': 2275.0}
# 2017-08-04 16:46:05,477 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:46:18,403 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:46:18,411 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=11396.71 pmax=2175.00 pavg=2030.04 pmin=2000.00 cmax=177.00 cmin=163.00 ]
# 2017-08-04 16:46:18,419 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:46:18,421 DEBUG   : EnergyMeter  : {'cmin': 163.0, 'energy': 11396.71, 'pavg': 2030.04, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 16:46:24,736 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:46:35,961 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:46:35,966 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=19671.93 pmax=2400.00 pavg=2190.04 pmin=1725.00 cmax=197.00 cmin=140.00 ]
# 2017-08-04 16:46:35,973 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:46:35,977 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 19671.93, 'pavg': 2190.04, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 197.0, 'pmax': 2400.0}
# 2017-08-04 16:46:42,024 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:46:53,260 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:46:53,261 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=19672.15 pmax=2400.00 pavg=2190.06 pmin=1725.00 cmax=197.00 cmin=140.00 ]
# 2017-08-04 16:46:53,264 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:46:53,268 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 19672.15, 'pavg': 2190.06, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 197.0, 'pmax': 2400.0}
# 2017-08-04 16:46:59,338 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:47:10,556 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:47:10,558 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=19736.62 pmax=2450.00 pavg=2197.24 pmin=1750.00 cmax=201.00 cmin=143.00 ]
# 2017-08-04 16:47:10,559 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:47:10,567 DEBUG   : EnergyMeter  : {'cmin': 143.0, 'energy': 19736.62, 'pavg': 2197.24, 'pmin': 1750.0, 'vmax': 12197.5, 'cmax': 201.0, 'pmax': 2450.0}
# 2017-08-04 16:47:16,823 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:47:26,952 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:47:26,966 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12196.25 energy=19239.04 pmax=2675.00 pavg=2447.82 pmin=1750.00 cmax=220.00 cmin=145.00 ]
# 2017-08-04 16:47:26,970 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:47:26,981 DEBUG   : EnergyMeter  : {'cmin': 145.0, 'energy': 19239.04, 'pavg': 2447.82, 'pmin': 1750.0, 'vmax': 12196.25, 'cmax': 220.0, 'pmax': 2675.0}
# 2017-08-04 16:47:33,052 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:47:43,156 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:47:43,162 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=19167.98 pmax=2725.00 pavg=2438.78 pmin=1725.00 cmax=222.00 cmin=141.00 ]
# 2017-08-04 16:47:43,179 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:47:43,183 DEBUG   : EnergyMeter  : {'cmin': 141.0, 'energy': 19167.98, 'pavg': 2438.78, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 222.0, 'pmax': 2725.0}
# 2017-08-04 16:47:49,245 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:47:59,396 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:47:59,409 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=19270.61 pmax=2700.00 pavg=2451.84 pmin=1725.00 cmax=220.00 cmin=142.00 ]
# 2017-08-04 16:47:59,412 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:47:59,420 DEBUG   : EnergyMeter  : {'cmin': 142.0, 'energy': 19270.61, 'pavg': 2451.84, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 220.0, 'pmax': 2700.0}
# 2017-08-04 16:48:05,678 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:48:14,694 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:48:14,705 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=17910.09 pmax=2950.00 pavg=2658.53 pmin=1750.00 cmax=242.00 cmin=145.00 ]
# 2017-08-04 16:48:14,709 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:48:14,716 DEBUG   : EnergyMeter  : {'cmin': 145.0, 'energy': 17910.09, 'pavg': 2658.53, 'pmin': 1750.0, 'vmax': 12197.5, 'cmax': 242.0, 'pmax': 2950.0}
# 2017-08-04 16:48:20,802 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:48:29,805 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:48:29,818 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=17851.75 pmax=2950.00 pavg=2649.87 pmin=1725.00 cmax=243.00 cmin=142.00 ]
# 2017-08-04 16:48:29,821 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:48:29,825 DEBUG   : EnergyMeter  : {'cmin': 142.0, 'energy': 17851.75, 'pavg': 2649.87, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 243.0, 'pmax': 2950.0}
# 2017-08-04 16:48:35,913 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:48:44,932 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:48:44,942 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12197.50 energy=17872.81 pmax=2950.00 pavg=2652.99 pmin=1725.00 cmax=242.00 cmin=142.00 ]
# 2017-08-04 16:48:44,948 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:48:44,953 DEBUG   : EnergyMeter  : {'cmin': 142.0, 'energy': 17872.81, 'pavg': 2652.99, 'pmin': 1725.0, 'vmax': 12197.5, 'cmax': 242.0, 'pmax': 2950.0}
# 2017-08-04 16:48:49,986 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 0-3"
# 2017-08-04 16:48:50,197 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/mems] to: 0"
# 2017-08-04 16:48:50,376 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_ISOL/cpus] to: 4-7"
# 2017-08-04 16:48:50,542 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_ISOL/mems] to: 0"
# 2017-08-04 16:48:50,717 DEBUG   : root         : Moving all tasks into /DEVLIB_SBOX
# 2017-08-04 16:48:50,732 DEBUG   : root         :    using grep filter:
# 2017-08-04 16:48:52,336 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 4"
# 2017-08-04 16:48:52,563 INFO    : root         : Cluster PD_1     (Online CPUs : [4])
# 2017-08-04 16:48:53,781 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:49:06,128 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:49:06,137 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=18163.60 pmax=2050.00 pavg=1797.44 pmin=1550.00 cmax=167.00 cmin=127.00 ]
# 2017-08-04 16:49:06,146 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:49:06,153 DEBUG   : EnergyMeter  : {'cmin': 127.0, 'energy': 18163.6, 'pavg': 1797.44, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 167.0, 'pmax': 2050.0}
# 2017-08-04 16:49:12,232 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:49:24,571 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:49:24,581 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=17975.44 pmax=2025.00 pavg=1778.82 pmin=1550.00 cmax=165.00 cmin=126.00 ]
# 2017-08-04 16:49:24,591 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:49:24,593 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 17975.44, 'pavg': 1778.82, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 165.0, 'pmax': 2025.0}
# 2017-08-04 16:49:30,672 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:49:43,016 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:49:43,025 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=17856.36 pmax=2025.00 pavg=1767.04 pmin=1550.00 cmax=166.00 cmin=126.00 ]
# 2017-08-04 16:49:43,034 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:49:43,036 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 17856.36, 'pavg': 1767.04, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 166.0, 'pmax': 2025.0}
# 2017-08-04 16:49:49,260 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:50:01,599 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:50:01,609 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=19742.32 pmax=2275.00 pavg=1953.67 pmin=1525.00 cmax=188.00 cmin=126.00 ]
# 2017-08-04 16:50:01,615 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:50:01,619 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 19742.32, 'pavg': 1953.67, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 188.0, 'pmax': 2275.0}
# 2017-08-04 16:50:07,676 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:50:20,019 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:50:20,025 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=19719.08 pmax=2275.00 pavg=1951.37 pmin=1550.00 cmax=187.00 cmin=126.00 ]
# 2017-08-04 16:50:20,035 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:50:20,045 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 19719.08, 'pavg': 1951.37, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 187.0, 'pmax': 2275.0}
# 2017-08-04 16:50:26,098 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:50:38,423 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:50:38,429 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=19720.83 pmax=2300.00 pavg=1951.54 pmin=1525.00 cmax=188.00 cmin=126.00 ]
# 2017-08-04 16:50:38,430 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:50:38,434 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 19720.83, 'pavg': 1951.54, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 188.0, 'pmax': 2300.0}
# 2017-08-04 16:50:44,594 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:50:56,923 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:50:56,937 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=21788.82 pmax=2600.00 pavg=2156.18 pmin=1550.00 cmax=214.00 cmin=126.00 ]
# 2017-08-04 16:50:56,939 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:50:56,950 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 21788.82, 'pavg': 2156.18, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 214.0, 'pmax': 2600.0}
# 2017-08-04 16:51:03,028 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:51:15,366 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:51:15,373 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=21718.20 pmax=2625.00 pavg=2149.20 pmin=1550.00 cmax=214.00 cmin=126.00 ]
# 2017-08-04 16:51:15,378 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:51:15,385 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 21718.2, 'pavg': 2149.2, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 214.0, 'pmax': 2625.0}
# 2017-08-04 16:51:21,462 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:51:33,805 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:51:33,807 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=21763.82 pmax=2625.00 pavg=2153.71 pmin=1550.00 cmax=217.00 cmin=126.00 ]
# 2017-08-04 16:51:33,815 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:51:33,816 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 21763.82, 'pavg': 2153.71, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 217.0, 'pmax': 2625.0}
# 2017-08-04 16:51:40,002 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:51:52,342 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:51:52,343 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=24745.18 pmax=3225.00 pavg=2448.74 pmin=1550.00 cmax=265.00 cmin=126.00 ]
# 2017-08-04 16:51:52,349 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:51:52,356 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 24745.18, 'pavg': 2448.74, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 265.0, 'pmax': 3225.0}
# 2017-08-04 16:51:58,412 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:52:10,758 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:52:10,769 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=24918.86 pmax=2975.00 pavg=2465.93 pmin=1550.00 cmax=243.00 cmin=126.00 ]
# 2017-08-04 16:52:10,776 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:52:10,785 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 24918.86, 'pavg': 2465.93, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 243.0, 'pmax': 2975.0}
# 2017-08-04 16:52:16,866 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:52:29,195 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:52:29,205 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=24843.20 pmax=2900.00 pavg=2458.44 pmin=1550.00 cmax=237.00 cmin=126.00 ]
# 2017-08-04 16:52:29,211 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:52:29,217 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 24843.2, 'pavg': 2458.44, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 237.0, 'pmax': 2900.0}
# 2017-08-04 16:52:35,437 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:52:47,788 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:52:47,790 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=30676.75 pmax=3600.00 pavg=3035.72 pmin=1550.00 cmax=295.00 cmin=126.00 ]
# 2017-08-04 16:52:47,797 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# ...
# 2017-08-04 16:59:35,298 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 25768.64, 'pavg': 2550.02, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 229.0, 'pmax': 2800.0}
# 2017-08-04 16:59:41,341 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 16:59:53,679 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 16:59:53,689 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=25730.70 pmax=2800.00 pavg=2546.27 pmin=1550.00 cmax=230.00 cmin=128.00 ]
# 2017-08-04 16:59:53,693 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 16:59:53,702 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 25730.7, 'pavg': 2546.27, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 230.0, 'pmax': 2800.0}
# 2017-08-04 16:59:59,949 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:00:11,188 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:00:11,201 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=28313.16 pmax=3525.00 pavg=3152.05 pmin=1675.00 cmax=289.00 cmin=139.00 ]
# 2017-08-04 17:00:11,202 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:00:11,204 DEBUG   : EnergyMeter  : {'cmin': 139.0, 'energy': 28313.16, 'pavg': 3152.05, 'pmin': 1675.0, 'vmax': 12198.75, 'cmax': 289.0, 'pmax': 3525.0}
# 2017-08-04 17:00:17,268 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:00:28,500 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:00:28,509 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=28308.55 pmax=3550.00 pavg=3151.54 pmin=1550.00 cmax=292.00 cmin=128.00 ]
# 2017-08-04 17:00:28,517 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:00:28,519 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 28308.55, 'pavg': 3151.54, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 292.0, 'pmax': 3550.0}
# 2017-08-04 17:00:34,597 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:00:45,822 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:00:45,833 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=28160.09 pmax=3525.00 pavg=3135.01 pmin=1550.00 cmax=288.00 cmin=128.00 ]
# 2017-08-04 17:00:45,835 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:00:45,841 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 28160.09, 'pavg': 3135.01, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 288.0, 'pmax': 3525.0}
# 2017-08-04 17:00:52,087 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:01:02,213 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:01:02,218 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12196.25 energy=31486.18 pmax=4525.00 pavg=4006.05 pmin=1800.00 cmax=371.00 cmin=149.00 ]
# 2017-08-04 17:01:02,228 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:01:02,235 DEBUG   : EnergyMeter  : {'cmin': 149.0, 'energy': 31486.18, 'pavg': 4006.05, 'pmin': 1800.0, 'vmax': 12196.25, 'cmax': 371.0, 'pmax': 4525.0}
# 2017-08-04 17:01:08,309 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:01:18,445 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:01:18,453 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=31433.55 pmax=4525.00 pavg=3999.36 pmin=1575.00 cmax=372.00 cmin=129.00 ]
# 2017-08-04 17:01:18,461 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:01:18,465 DEBUG   : EnergyMeter  : {'cmin': 129.0, 'energy': 31433.55, 'pavg': 3999.36, 'pmin': 1575.0, 'vmax': 12200.0, 'cmax': 372.0, 'pmax': 4525.0}
# 2017-08-04 17:01:24,548 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:01:34,684 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:01:34,686 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=31338.82 pmax=4525.00 pavg=3987.30 pmin=1600.00 cmax=372.00 cmin=130.00 ]
# 2017-08-04 17:01:34,691 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:01:34,692 DEBUG   : EnergyMeter  : {'cmin': 130.0, 'energy': 31338.82, 'pavg': 3987.3, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 372.0, 'pmax': 4525.0}
# 2017-08-04 17:01:40,913 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:01:51,036 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:01:51,041 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=33495.39 pmax=5600.00 pavg=4261.69 pmin=2100.00 cmax=463.00 cmin=173.00 ]
# 2017-08-04 17:01:51,046 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:01:51,050 DEBUG   : EnergyMeter  : {'cmin': 173.0, 'energy': 33495.39, 'pavg': 4261.69, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 463.0, 'pmax': 5600.0}
# 2017-08-04 17:01:57,110 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:02:07,220 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:02:07,222 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=32422.81 pmax=5675.00 pavg=4125.22 pmin=1600.00 cmax=467.00 cmin=131.00 ]
# 2017-08-04 17:02:07,230 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:02:07,232 DEBUG   : EnergyMeter  : {'cmin': 131.0, 'energy': 32422.81, 'pavg': 4125.22, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 467.0, 'pmax': 5675.0}
# 2017-08-04 17:02:13,298 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:02:24,536 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:02:24,545 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=36292.98 pmax=5675.00 pavg=4040.43 pmin=1625.00 cmax=469.00 cmin=133.00 ]
# 2017-08-04 17:02:24,553 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:02:24,557 DEBUG   : EnergyMeter  : {'cmin': 133.0, 'energy': 36292.98, 'pavg': 4040.43, 'pmin': 1625.0, 'vmax': 12200.0, 'cmax': 469.0, 'pmax': 5675.0}
# 2017-08-04 17:02:29,879 DEBUG   : cgroups.cpuset : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh5/DEVLIB_SBOX/cpus] to: 4-7"
# 2017-08-04 17:02:30,071 INFO    : root         : Cluster PD_1     (Online CPUs : [4, 5, 6, 7])
# 2017-08-04 17:02:31,257 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:02:43,606 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:02:43,614 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=23156.14 pmax=2500.00 pavg=2291.49 pmin=1725.00 cmax=205.00 cmin=140.00 ]
# 2017-08-04 17:02:43,619 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:02:43,625 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 23156.14, 'pavg': 2291.49, 'pmin': 1725.0, 'vmax': 12198.75, 'cmax': 205.0, 'pmax': 2500.0}
# 2017-08-04 17:02:49,707 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:03:02,052 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:03:02,062 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=22914.04 pmax=2475.00 pavg=2267.53 pmin=1675.00 cmax=202.00 cmin=136.00 ]
# 2017-08-04 17:03:02,070 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:03:02,073 DEBUG   : EnergyMeter  : {'cmin': 136.0, 'energy': 22914.04, 'pavg': 2267.53, 'pmin': 1675.0, 'vmax': 12200.0, 'cmax': 202.0, 'pmax': 2475.0}
# 2017-08-04 17:03:08,158 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:03:20,504 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:03:20,514 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=22703.29 pmax=2475.00 pavg=2246.68 pmin=1550.00 cmax=202.00 cmin=128.00 ]
# 2017-08-04 17:03:20,522 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:03:20,526 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 22703.29, 'pavg': 2246.68, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 202.0, 'pmax': 2475.0}
# 2017-08-04 17:03:26,800 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:03:36,915 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:03:36,930 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=22193.42 pmax=3150.00 pavg=2823.72 pmin=1550.00 cmax=258.00 cmin=128.00 ]
# 2017-08-04 17:03:36,935 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:03:36,944 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 22193.42, 'pavg': 2823.72, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 258.0, 'pmax': 3150.0}
# 2017-08-04 17:03:43,007 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:03:54,242 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:03:54,250 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=25544.30 pmax=3175.00 pavg=2843.80 pmin=1550.00 cmax=260.00 cmin=129.00 ]
# 2017-08-04 17:03:54,261 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:03:54,266 DEBUG   : EnergyMeter  : {'cmin': 129.0, 'energy': 25544.3, 'pavg': 2843.8, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 260.0, 'pmax': 3175.0}
# 2017-08-04 17:04:00,348 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:04:10,483 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:04:10,487 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=22088.82 pmax=3150.00 pavg=2810.41 pmin=1550.00 cmax=257.00 cmin=128.00 ]
# 2017-08-04 17:04:10,493 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:04:10,498 DEBUG   : EnergyMeter  : {'cmin': 128.0, 'energy': 22088.82, 'pavg': 2810.41, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 257.0, 'pmax': 3150.0}
# 2017-08-04 17:04:16,731 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:04:25,733 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:04:25,741 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12198.75 energy=24227.41 pmax=4075.00 pavg=3596.26 pmin=1725.00 cmax=337.00 cmin=140.00 ]
# 2017-08-04 17:04:25,743 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:04:25,752 DEBUG   : EnergyMeter  : {'cmin': 140.0, 'energy': 24227.41, 'pavg': 3596.26, 'pmin': 1725.0, 'vmax': 12198.75, 'cmax': 337.0, 'pmax': 4075.0}
# 2017-08-04 17:04:31,857 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:04:40,927 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:04:40,935 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=24237.72 pmax=4125.00 pavg=3597.79 pmin=1550.00 cmax=339.00 cmin=129.00 ]
# 2017-08-04 17:04:40,943 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:04:40,949 DEBUG   : EnergyMeter  : {'cmin': 129.0, 'energy': 24237.72, 'pavg': 3597.79, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 339.0, 'pmax': 4125.0}
# 2017-08-04 17:04:47,036 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:04:56,044 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:04:56,057 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=24177.85 pmax=4150.00 pavg=3588.90 pmin=1575.00 cmax=340.00 cmin=129.00 ]
# 2017-08-04 17:04:56,065 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:04:56,069 DEBUG   : EnergyMeter  : {'cmin': 129.0, 'energy': 24177.85, 'pavg': 3588.9, 'pmin': 1575.0, 'vmax': 12201.25, 'cmax': 340.0, 'pmax': 4150.0}
# 2017-08-04 17:05:02,290 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:05:10,192 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:05:10,200 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=23846.27 pmax=5250.00 pavg=4247.62 pmin=1600.00 cmax=433.00 cmin=130.00 ]
# 2017-08-04 17:05:10,202 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:05:10,204 DEBUG   : EnergyMeter  : {'cmin': 130.0, 'energy': 23846.27, 'pavg': 4247.62, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 433.0, 'pmax': 5250.0}
# 2017-08-04 17:05:16,265 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:05:24,187 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:05:24,197 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=23882.46 pmax=5300.00 pavg=4254.06 pmin=1600.00 cmax=436.00 cmin=130.00 ]
# 2017-08-04 17:05:24,199 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:05:24,202 DEBUG   : EnergyMeter  : {'cmin': 130.0, 'energy': 23882.46, 'pavg': 4254.06, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 436.0, 'pmax': 5300.0}
# 2017-08-04 17:05:30,260 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:05:39,277 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:05:39,282 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=28380.04 pmax=5350.00 pavg=4212.66 pmin=1600.00 cmax=439.00 cmin=132.00 ]
# 2017-08-04 17:05:39,290 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:05:39,292 DEBUG   : EnergyMeter  : {'cmin': 132.0, 'energy': 28380.04, 'pavg': 4212.66, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 439.0, 'pmax': 5350.0}
# 2017-08-04 17:05:45,479 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:05:54,499 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:05:54,506 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=29583.33 pmax=6750.00 pavg=4391.28 pmin=1600.00 cmax=556.00 cmin=131.00 ]
# 2017-08-04 17:05:54,513 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:05:54,515 DEBUG   : EnergyMeter  : {'cmin': 131.0, 'energy': 29583.33, 'pavg': 4391.28, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 556.0, 'pmax': 6750.0}
# 2017-08-04 17:06:00,594 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:06:09,644 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:06:09,654 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=29216.67 pmax=6700.00 pavg=4336.85 pmin=1600.00 cmax=552.00 cmin=131.00 ]
# 2017-08-04 17:06:09,663 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:06:09,665 DEBUG   : EnergyMeter  : {'cmin': 131.0, 'energy': 29216.67, 'pavg': 4336.85, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 552.0, 'pmax': 6700.0}
# 2017-08-04 17:06:15,717 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:06:24,736 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:06:24,746 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12200.00 energy=28631.58 pmax=6650.00 pavg=4250.00 pmin=1600.00 cmax=549.00 cmin=132.00 ]
# 2017-08-04 17:06:24,757 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:06:24,759 DEBUG   : EnergyMeter  : {'cmin': 132.0, 'energy': 28631.58, 'pavg': 4250.0, 'pmin': 1600.0, 'vmax': 12200.0, 'cmax': 549.0, 'pmax': 6650.0}
# 2017-08-04 17:06:29,788 DEBUG   : cgroups.freezer : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh0/DEVLIB_FREEZER/freezer.state] to: THAWED"
# 2017-08-04 17:06:29,992 DEBUG   : root         : Moving all tasks into /
# 2017-08-04 17:06:30,001 DEBUG   : root         :    using grep filter:

# %%
def plot_pstates(power_perf_df, cluster):
    """
    Plot P-States profiling for the specified cluster.
    
    :param power_perf_df: DataFrame reporting power and performance values
    :type power_perf_df: :mod:`pandas.DataFrame`
    
    :param cluster: cluster description
    :type cluster: namedtuple(ClusterDescription)
    """
    cmap = ColorMap(len(cluster.freqs))
    color_map = map(cmap.cmap, range(len(cluster.freqs)))
    color_map = dict(zip(cluster.freqs, color_map))
    
    fig, ax = plt.subplots(1, 1, figsize=(16, 10))
    
    grouped = power_perf_df.loc[cluster.name].groupby(level='freq')
    for freq, df in grouped:
        x = df.index.get_level_values('cpus').tolist()
        y = df.power.tolist()
        slope, intercept = linfit(x, y)
        x.insert(0, 0)
        y.insert(0, intercept)
        # Plot linear fit of the points
        ax.plot(x, [slope*i + intercept for i in x], color=color_map[freq])
        # Plot measured points
        ax.scatter(x, y, color=color_map[freq], label='{} kHz'.format(freq))

    ax.set_title('HiKey {} cluster P-States profiling'.format(cluster.name),
                 fontsize=16)
    ax.legend()
    ax.set_xlabel('Active cores')
    ax.set_ylabel('Power [$\mu$W]')
    ax.set_xlim(-0.5, len(cluster.cpus)+1)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax.grid(True)

# %%
pd0_cl = clusters[0]

plot_pstates(power_perf_df, pd0_cl)

# %% [markdown]
# ### Statistics

# %%
def power_perf_stats(power_perf_df):
    """
    For each cluster compute per-OPP power and performance statistics.
    
    :param power_perf_df: dataframe containing power and performance numbers
    :type power_perf_df: :mod:`pandas.DataFrame`
    """
    clusters = power_perf_df.index.get_level_values('cluster')\
                                  .unique().tolist()

    stats = []   
    for cl in clusters:
        cl_power_df = power_perf_df.loc[cl].reset_index()

        grouped = cl_power_df.groupby('freq')
        for freq, df in grouped:
            perf = df['perf'] / df['cpus']
            power = df['power'] / df['cpus']
            energy = df['energy'] / df['cpus']

            avg_row = {'cluster': cl,
                       'freq': freq,
                       'stats': 'avg',
                       'perf': perf.mean(),
                       'power': power.mean(),
                       'energy': energy.mean()
                      }
            std_row = {'cluster': cl,
                       'freq': freq,
                       'stats': 'std',
                       'perf': perf.std(),
                       'power': power.std(),
                       'energy': energy.std()
                      }
            min_row = {'cluster': cl,
                       'freq': freq,
                       'stats': 'min',
                       'perf': perf.min(),
                       'power': power.min(),
                       'energy': energy.min()
                      }
            max_row = {'cluster' : cl,
                       'freq' : freq,
                       'stats' : 'max',
                       'perf' : perf.max(),
                       'power' : power.max(),
                       'energy': energy.max()
                      }
            c99_row = {'cluster' : cl,
                       'freq' : freq,
                       'stats' : 'c99',
                       'perf' : perf.quantile(q=0.99),
                       'power' : power.quantile(q=0.99),
                       'energy': energy.quantile(q=0.99)
                      }

            stats.append(avg_row)
            stats.append(std_row)
            stats.append(min_row)
            stats.append(max_row)
            stats.append(c99_row)
    
    stats_df = pd.DataFrame(stats).set_index(['cluster', 'freq', 'stats'])\
                                  .sort_index(level='cluster')
    return stats_df.unstack()

# %%
pp_stats = power_perf_stats(power_perf_df)

# %% [markdown]
# ### Plots

# %%
def plot_power_perf(pp_stats, clusters):
    cmap = ColorMap(len(clusters) + 1)
    color_map = map(cmap.cmap, range(len(clusters) + 1))
    
    fig, ax = plt.subplots(1, 1, figsize=(16, 10))

    max_perf = pp_stats.perf['avg'].max()
    max_power = pp_stats.power['avg'].max()

    for i, cl in enumerate(clusters):
        cl_df = pp_stats.loc[cl.name]
        norm_perf_df = cl_df.perf['avg'] * 100.0 / max_perf
        norm_power_df = cl_df.power['avg'] * 100.0 / max_power

        x = norm_perf_df.values.tolist()
        y = norm_power_df.values.tolist()
        ax.plot(x, y, color=color_map[i], marker='o', label=cl.name)

        norm_perf_df = cl_df.perf['max'] * 100.0 / max_perf
        norm_power_df = cl_df.power['max'] * 100.0 / max_power

        x = norm_perf_df.values.tolist()
        y = norm_power_df.values.tolist()
        ax.plot(x, y, '--', color=color_map[-1])

        norm_perf_df = cl_df.perf['min'] * 100.0 / max_perf
        norm_power_df = cl_df.power['min'] * 100.0 / max_power

        x = norm_perf_df.values.tolist()
        y = norm_power_df.values.tolist()
        ax.plot(x, y, '--', color=color_map[-1])

    ax.set_title('HyKey Power VS Performance curves', fontsize=16)
    ax.legend()
    ax.set_xlabel('Performance [%]')
    ax.set_ylabel('Power [%]')
    ax.set_xlim(0, 120)
    ax.set_ylim(0, 120)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.grid(True)

# %%
plot_power_perf(pp_stats, clusters)

# %% [markdown]
# ## Idle States Profiling

# %%
def compute_idle_power(clusters, loop_cnt, sleep_duration, bkp_file='cstates.csv'):
    """
    Perform C-States profiling on each input cluster.
    
    Data will be saved into a CSV file at each iteration such that if something
    goes wrong the user can restart the experiment considering only idle_states
    that had not been processed.
    
    :param clusters: list of clusters to profile
    :type clusters: list(namedtuple(ClusterDescription))
    
    :param loop_cnt: number of loops for each experiment
    :type loop_cnt: int
    
    :param sleep_duration: sleep time in seconds
    :type sleep_duration: int
    
    :param bkp_file: CSV file name
    :type bkp_file: str
    """

    # Make sure all CPUs are online
    target.hotplug.online_all()

    with open(bkp_file, 'w') as csvfile:
        writer = DictWriter(csvfile, fieldnames=['cluster', 'cpus',
                                                 'idle_state', 'energy', 'power'])

        # Disable frequency scaling by setting cpufreq governor to userspace
        target.cpufreq.set_all_governors('userspace')

        # Freeze all tasks but the ones to communicate with the target
        target.cgroups.freeze(exclude=CRITICAL_TASKS['android'])

        all_cpus = set(range(target.number_of_cpus))
        idle_power = []
        for cl in clusters:

            # In current cluster, hotplug OFF all CPUs but the first one
            # At least one CPU must be online
            target.hotplug.online(cl.cpus[0])
            for cpu in cl.cpus[1:]:
                target.hotplug.offline(cpu)

            other_cpus = list(all_cpus - set(cl.cpus))
            # CPUs in the other clusters will be kept hotplugged OFF
            # to not affect measurements on the current cluster
            for cpu in other_cpus:
                target.hotplug.offline(cpu)

            # B) For each additional cluster's plugged in CPU...
            for cnt, cpu in enumerate(cl.cpus):
                
                # Hotplug ON one more CPU
                target.hotplug.online(cpu)
                
                cl_cpus = set(target.list_online_cpus()).intersection(set(cl.cpus))
                logging.info('Cluster {:8} (Online CPUs : {})'\
                              .format(cl.name, list(cl_cpus)))

                for idle in cl.idle_states:

                    # Disable all idle states but the current one
                    for c in cl.cpus:
                        target.cpuidle.disable_all(cpu=c)
                        target.cpuidle.enable(idle, cpu=c)

                    sleep(3)
                    # Sleep for the specified duration each time collecting a sample
                    # of energy consumption and reported performance
                    energy = 0.0
                    for i in xrange(loop_cnt):
                        te.emeter.reset()
                        sleep(sleep_duration)
                        nrg = te.emeter.report(te.res_dir).channels
                        energy += float(nrg[cl.emeter_ch])

                    # Compute average energy and performance for the current number of
                    # active CPUs all idle at the current OPP
                    energy = energy / loop_cnt
                    power = energy / SLEEP_DURATION

                    # Keep track of this new C-State profiling point
                    new_row = {'cluster': cl.name,
                               'cpus': cnt + 1,
                               'idle_state': idle,
                               'energy': energy,
                               'power': power}
                    idle_power.append(new_row)

                    # Save data in a CSV file
                    writer.writerow(new_row)
                    
                # C) profile next C-State

            # B) add one more CPU (for the current frequency domain)

        # A) profile next cluster (i.e. frequency domain)

        # Thaw all tasks in the freezer cgroup
        target.cgroups.freeze(thaw=True)
        target.hotplug.online_all()

        idle_df = pd.DataFrame(idle_power)
    return idle_df.set_index(['cluster', 'idle_state', 'cpus']).sort_index(level='cluster')

# %%
SLEEP_DURATION = 10
loop_cnt = 3

idle_df = compute_idle_power(clusters, loop_cnt, SLEEP_DURATION)
# Out:
# 2017-08-04 17:11:03,124 DEBUG   : root         : Moving all tasks into /DEVLIB_FREEZER
# 2017-08-04 17:11:03,131 DEBUG   : root         :    using grep filter: -e /system/bin/sh -e adbd -e /init
# 2017-08-04 17:11:03,133 DEBUG   : root         :    excluding tasks which name matches:
# 2017-08-04 17:11:03,135 DEBUG   : root         :    /system/bin/sh, adbd, /init
# 2017-08-04 17:11:03,590 DEBUG   : cgroups.freezer : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh0/DEVLIB_FREEZER/freezer.state] to: FROZEN"
# 2017-08-04 17:11:05,567 INFO    : root         : Cluster PD_0     (Online CPUs : [0])
# 2017-08-04 17:11:12,458 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:11:25,362 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:11:25,364 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=8592.32 pmax=1675.00 pavg=1530.51 pmin=1525.00 cmax=136.00 cmin=125.00 ]
# 2017-08-04 17:11:25,366 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:11:25,367 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 8592.32, 'pavg': 1530.51, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 136.0, 'pmax': 1675.0}
# 2017-08-04 17:11:26,431 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:11:38,786 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:11:38,787 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15460.53 pmax=1675.00 pavg=1529.95 pmin=1525.00 cmax=136.00 cmin=125.00 ]
# 2017-08-04 17:11:38,789 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:11:38,794 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15460.53, 'pavg': 1529.95, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 136.0, 'pmax': 1675.0}
# 2017-08-04 17:11:39,891 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:11:52,233 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:11:52,235 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15467.54 pmax=1650.00 pavg=1530.64 pmin=1525.00 cmax=135.00 cmin=125.00 ]
# 2017-08-04 17:11:52,236 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:11:52,245 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15467.54, 'pavg': 1530.64, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:11:58,858 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:12:11,190 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:12:11,191 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15441.67 pmax=1650.00 pavg=1528.08 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:12:11,193 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:12:11,194 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15441.67, 'pavg': 1528.08, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:12:12,245 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:12:24,596 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:12:24,598 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15442.76 pmax=1650.00 pavg=1528.19 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:12:24,599 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:12:24,600 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15442.76, 'pavg': 1528.19, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:12:25,682 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:12:38,036 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:12:38,038 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15438.38 pmax=1650.00 pavg=1527.76 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:12:38,041 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:12:38,050 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15438.38, 'pavg': 1527.76, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:12:44,680 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:12:57,036 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:12:57,037 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=12762.72 pmax=1575.00 pavg=1262.98 pmin=1175.00 cmax=128.00 cmin=95.00 ]
# 2017-08-04 17:12:57,039 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:12:57,049 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 12762.72, 'pavg': 1262.98, 'pmin': 1175.0, 'vmax': 12207.5, 'cmax': 128.0, 'pmax': 1575.0}
# 2017-08-04 17:12:58,115 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:13:10,493 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:13:10,501 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=12440.79 pmax=1525.00 pavg=1231.12 pmin=1150.00 cmax=125.00 cmin=95.00 ]
# 2017-08-04 17:13:10,503 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:13:10,505 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 12440.79, 'pavg': 1231.12, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 125.0, 'pmax': 1525.0}
# 2017-08-04 17:13:11,623 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:13:23,991 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:13:24,002 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=12713.16 pmax=2000.00 pavg=1258.07 pmin=1150.00 cmax=164.00 cmin=95.00 ]
# 2017-08-04 17:13:24,006 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:13:24,013 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 12713.16, 'pavg': 1258.07, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 164.0, 'pmax': 2000.0}
# 2017-08-04 17:13:24,480 INFO    : root         : Cluster PD_0     (Online CPUs : [0, 1])
# 2017-08-04 17:13:31,391 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:13:43,753 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:13:43,761 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15514.25 pmax=2050.00 pavg=1535.26 pmin=1525.00 cmax=168.00 cmin=125.00 ]
# 2017-08-04 17:13:43,771 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:13:43,774 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15514.25, 'pavg': 1535.26, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 168.0, 'pmax': 2050.0}
# 2017-08-04 17:13:44,870 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:13:57,210 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:13:57,217 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15527.63 pmax=2100.00 pavg=1536.59 pmin=1525.00 cmax=173.00 cmin=125.00 ]
# 2017-08-04 17:13:57,220 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:13:57,230 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15527.63, 'pavg': 1536.59, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 173.0, 'pmax': 2100.0}
# 2017-08-04 17:13:58,334 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:14:10,670 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:14:10,677 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15546.27 pmax=2075.00 pavg=1538.43 pmin=1525.00 cmax=171.00 cmin=125.00 ]
# 2017-08-04 17:14:10,681 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:14:10,689 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15546.27, 'pavg': 1538.43, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 171.0, 'pmax': 2075.0}
# 2017-08-04 17:14:17,613 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:14:29,955 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:14:29,963 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15464.47 pmax=1675.00 pavg=1530.34 pmin=1525.00 cmax=136.00 cmin=124.00 ]
# 2017-08-04 17:14:29,969 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:14:29,977 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15464.47, 'pavg': 1530.34, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 136.0, 'pmax': 1675.0}
# 2017-08-04 17:14:31,066 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:14:43,422 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:14:43,423 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15438.38 pmax=1650.00 pavg=1527.76 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:14:43,429 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:14:43,430 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15438.38, 'pavg': 1527.76, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:14:44,515 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:14:56,859 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:14:56,865 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15436.84 pmax=1650.00 pavg=1527.60 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:14:56,875 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:14:56,877 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15436.84, 'pavg': 1527.6, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:15:03,730 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:15:16,090 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:15:16,101 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=12558.55 pmax=1525.00 pavg=1242.77 pmin=1150.00 cmax=124.00 cmin=95.00 ]
# 2017-08-04 17:15:16,105 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:15:16,113 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 12558.55, 'pavg': 1242.77, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 124.0, 'pmax': 1525.0}
# 2017-08-04 17:15:17,210 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:15:29,564 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:15:29,572 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=12386.18 pmax=1625.00 pavg=1225.72 pmin=1150.00 cmax=133.00 cmin=95.00 ]
# 2017-08-04 17:15:29,575 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:15:29,577 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 12386.18, 'pavg': 1225.72, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 133.0, 'pmax': 1625.0}
# 2017-08-04 17:15:30,696 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:15:43,054 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:15:43,061 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12207.50 energy=12332.24 pmax=1550.00 pavg=1220.38 pmin=1150.00 cmax=129.00 cmin=95.00 ]
# 2017-08-04 17:15:43,073 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:15:43,076 DEBUG   : EnergyMeter  : {'cmin': 95.0, 'energy': 12332.24, 'pavg': 1220.38, 'pmin': 1150.0, 'vmax': 12207.5, 'cmax': 129.0, 'pmax': 1550.0}
# 2017-08-04 17:15:43,556 INFO    : root         : Cluster PD_0     (Online CPUs : [0, 1, 2])
# 2017-08-04 17:15:50,430 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:16:02,781 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:16:02,788 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15673.68 pmax=1675.00 pavg=1551.04 pmin=1525.00 cmax=137.00 cmin=125.00 ]
# 2017-08-04 17:16:02,797 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:16:02,803 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15673.68, 'pavg': 1551.04, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 137.0, 'pmax': 1675.0}
# 2017-08-04 17:16:03,887 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:16:16,239 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:16:16,245 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15684.65 pmax=1675.00 pavg=1552.13 pmin=1525.00 cmax=137.00 cmin=125.00 ]
# 2017-08-04 17:16:16,247 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:16:16,252 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15684.65, 'pavg': 1552.13, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 137.0, 'pmax': 1675.0}
# 2017-08-04 17:16:17,386 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:16:29,756 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:16:29,760 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15683.33 pmax=1675.00 pavg=1552.00 pmin=1525.00 cmax=136.00 cmin=125.00 ]
# 2017-08-04 17:16:29,767 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:16:29,773 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15683.33, 'pavg': 1552.0, 'pmin': 1525.0, 'vmax': 12201.25, 'cmax': 136.0, 'pmax': 1675.0}
# 2017-08-04 17:16:36,618 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:16:48,964 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:16:48,972 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15435.96 pmax=1650.00 pavg=1527.52 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:16:48,980 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:16:48,989 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15435.96, 'pavg': 1527.52, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:16:50,093 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:17:02,447 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:17:02,457 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15435.09 pmax=1650.00 pavg=1527.43 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:17:02,463 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:17:02,470 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15435.09, 'pavg': 1527.43, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:17:03,591 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:17:15,950 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:17:15,961 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15436.18 pmax=1650.00 pavg=1527.54 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:17:15,966 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:17:15,968 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15436.18, 'pavg': 1527.54, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:17:22,772 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:17:35,122 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:17:35,127 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15472.59 pmax=1650.00 pavg=1531.14 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:17:35,135 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:17:35,141 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15472.59, 'pavg': 1531.14, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:17:36,257 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:17:48,599 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:17:48,606 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15466.23 pmax=1650.00 pavg=1530.51 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:17:48,610 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:17:48,620 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15466.23, 'pavg': 1530.51, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:17:49,738 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:18:02,070 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:18:02,077 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15460.53 pmax=1650.00 pavg=1529.95 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:18:02,084 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:18:02,092 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15460.53, 'pavg': 1529.95, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:18:02,594 INFO    : root         : Cluster PD_0     (Online CPUs : [0, 1, 2, 3])
# 2017-08-04 17:18:09,397 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:18:21,760 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:18:21,764 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15686.40 pmax=1675.00 pavg=1552.30 pmin=1550.00 cmax=138.00 cmin=126.00 ]
# 2017-08-04 17:18:21,770 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:18:21,778 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 15686.4, 'pavg': 1552.3, 'pmin': 1550.0, 'vmax': 12202.5, 'cmax': 138.0, 'pmax': 1675.0}
# 2017-08-04 17:18:22,899 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:18:35,342 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:18:35,344 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15686.84 pmax=1675.00 pavg=1552.34 pmin=1550.00 cmax=138.00 cmin=126.00 ]
# 2017-08-04 17:18:35,346 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:18:35,347 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 15686.84, 'pavg': 1552.34, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 138.0, 'pmax': 1675.0}
# 2017-08-04 17:18:36,478 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:18:48,858 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:18:48,863 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12201.25 energy=15683.77 pmax=1675.00 pavg=1552.04 pmin=1550.00 cmax=137.00 cmin=126.00 ]
# 2017-08-04 17:18:48,873 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:18:48,881 DEBUG   : EnergyMeter  : {'cmin': 126.0, 'energy': 15683.77, 'pavg': 1552.04, 'pmin': 1550.0, 'vmax': 12201.25, 'cmax': 137.0, 'pmax': 1675.0}
# 2017-08-04 17:18:55,786 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:19:08,125 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:19:08,129 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15433.99 pmax=1650.00 pavg=1527.32 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:19:08,138 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:19:08,140 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15433.99, 'pavg': 1527.32, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:19:09,233 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:19:21,576 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:19:21,583 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15437.50 pmax=1675.00 pavg=1527.67 pmin=1525.00 cmax=136.00 cmin=124.00 ]
# 2017-08-04 17:19:21,591 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:19:21,593 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15437.5, 'pavg': 1527.67, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 136.0, 'pmax': 1675.0}
# 2017-08-04 17:19:22,690 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:19:35,020 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:19:35,023 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15433.55 pmax=1650.00 pavg=1527.28 pmin=1525.00 cmax=134.00 cmin=124.00 ]
# 2017-08-04 17:19:35,026 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:19:35,034 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15433.55, 'pavg': 1527.28, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 134.0, 'pmax': 1650.0}
# 2017-08-04 17:19:41,916 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:19:54,249 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:19:54,253 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15466.45 pmax=1675.00 pavg=1530.53 pmin=1525.00 cmax=137.00 cmin=125.00 ]
# 2017-08-04 17:19:54,258 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:19:54,265 DEBUG   : EnergyMeter  : {'cmin': 125.0, 'energy': 15466.45, 'pavg': 1530.53, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 137.0, 'pmax': 1675.0}
# 2017-08-04 17:19:55,352 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:20:07,718 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:20:07,728 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15468.20 pmax=1650.00 pavg=1530.71 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:20:07,735 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:20:07,745 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15468.2, 'pavg': 1530.71, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:20:08,876 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:20:21,225 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:20:21,234 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12202.50 energy=15468.20 pmax=1650.00 pavg=1530.71 pmin=1525.00 cmax=135.00 cmin=124.00 ]
# 2017-08-04 17:20:21,247 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:20:21,249 DEBUG   : EnergyMeter  : {'cmin': 124.0, 'energy': 15468.2, 'pavg': 1530.71, 'pmin': 1525.0, 'vmax': 12202.5, 'cmax': 135.0, 'pmax': 1650.0}
# 2017-08-04 17:20:23,167 INFO    : root         : Cluster PD_1     (Online CPUs : [4])
# 2017-08-04 17:20:29,526 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:20:41,872 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:20:41,877 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12195.00 energy=20231.14 pmax=2125.00 pavg=2002.04 pmin=2000.00 cmax=174.00 cmin=163.00 ]
# 2017-08-04 17:20:41,887 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:20:41,889 DEBUG   : EnergyMeter  : {'cmin': 163.0, 'energy': 20231.14, 'pavg': 2002.04, 'pmin': 2000.0, 'vmax': 12195.0, 'cmax': 174.0, 'pmax': 2125.0}
# 2017-08-04 17:20:42,991 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:20:55,344 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:20:55,348 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12195.00 energy=20235.09 pmax=2125.00 pavg=2002.43 pmin=2000.00 cmax=175.00 cmin=163.00 ]
# 2017-08-04 17:20:55,354 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:20:55,360 DEBUG   : EnergyMeter  : {'cmin': 163.0, 'energy': 20235.09, 'pavg': 2002.43, 'pmin': 2000.0, 'vmax': 12195.0, 'cmax': 175.0, 'pmax': 2125.0}
# 2017-08-04 17:20:56,452 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:21:08,804 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:21:08,810 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12195.00 energy=20235.53 pmax=2125.00 pavg=2002.47 pmin=2000.00 cmax=175.00 cmin=164.00 ]
# 2017-08-04 17:21:08,825 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:21:08,829 DEBUG   : EnergyMeter  : {'cmin': 164.0, 'energy': 20235.53, 'pavg': 2002.47, 'pmin': 2000.0, 'vmax': 12195.0, 'cmax': 175.0, 'pmax': 2125.0}
# 2017-08-04 17:21:15,118 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:21:27,460 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:21:27,462 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12195.00 energy=20232.68 pmax=2125.00 pavg=2002.19 pmin=2000.00 cmax=174.00 cmin=163.00 ]
# 2017-08-04 17:21:27,464 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:21:27,474 DEBUG   : EnergyMeter  : {'cmin': 163.0, 'energy': 20232.68, 'pavg': 2002.19, 'pmin': 2000.0, 'vmax': 12195.0, 'cmax': 174.0, 'pmax': 2125.0}
# 2017-08-04 17:21:28,548 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:21:40,912 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:21:40,922 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20237.94 pmax=2125.00 pavg=2002.71 pmin=2000.00 cmax=175.00 cmin=164.00 ]
# 2017-08-04 17:21:40,929 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:21:40,935 DEBUG   : EnergyMeter  : {'cmin': 164.0, 'energy': 20237.94, 'pavg': 2002.71, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 175.0, 'pmax': 2125.0}
# 2017-08-04 17:21:42,034 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:21:54,394 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:21:54,404 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12195.00 energy=20239.91 pmax=2125.00 pavg=2002.91 pmin=2000.00 cmax=176.00 cmin=164.00 ]
# 2017-08-04 17:21:54,413 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:21:54,416 DEBUG   : EnergyMeter  : {'cmin': 164.0, 'energy': 20239.91, 'pavg': 2002.91, 'pmin': 2000.0, 'vmax': 12195.0, 'cmax': 176.0, 'pmax': 2125.0}
# 2017-08-04 17:22:00,566 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:22:12,923 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:22:12,933 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20398.25 pmax=2175.00 pavg=2018.58 pmin=2000.00 cmax=177.00 cmin=165.00 ]
# 2017-08-04 17:22:12,943 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:22:12,945 DEBUG   : EnergyMeter  : {'cmin': 165.0, 'energy': 20398.25, 'pavg': 2018.58, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:22:14,047 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:22:26,427 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:22:26,436 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20382.02 pmax=2175.00 pavg=2016.97 pmin=2000.00 cmax=177.00 cmin=165.00 ]
# 2017-08-04 17:22:26,447 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:22:26,449 DEBUG   : EnergyMeter  : {'cmin': 165.0, 'energy': 20382.02, 'pavg': 2016.97, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:22:27,525 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:22:39,880 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:22:39,886 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20283.55 pmax=2125.00 pavg=2007.23 pmin=2000.00 cmax=176.00 cmin=165.00 ]
# 2017-08-04 17:22:39,895 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:22:39,905 DEBUG   : EnergyMeter  : {'cmin': 165.0, 'energy': 20283.55, 'pavg': 2007.23, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 176.0, 'pmax': 2125.0}
# 2017-08-04 17:22:40,225 INFO    : root         : Cluster PD_1     (Online CPUs : [4, 5])
# 2017-08-04 17:22:46,084 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:22:58,525 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:22:58,530 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20969.96 pmax=2200.00 pavg=2075.15 pmin=2050.00 cmax=181.00 cmin=168.00 ]
# 2017-08-04 17:22:58,539 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:22:58,549 DEBUG   : EnergyMeter  : {'cmin': 168.0, 'energy': 20969.96, 'pavg': 2075.15, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 181.0, 'pmax': 2200.0}
# 2017-08-04 17:22:59,621 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:23:11,978 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:23:11,990 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20913.38 pmax=2200.00 pavg=2069.55 pmin=2050.00 cmax=180.00 cmin=169.00 ]
# 2017-08-04 17:23:11,999 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:23:12,001 DEBUG   : EnergyMeter  : {'cmin': 169.0, 'energy': 20913.38, 'pavg': 2069.55, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 180.0, 'pmax': 2200.0}
# 2017-08-04 17:23:13,069 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:23:25,407 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:23:25,412 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20930.48 pmax=2200.00 pavg=2071.25 pmin=2050.00 cmax=180.00 cmin=169.00 ]
# 2017-08-04 17:23:25,420 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:23:25,426 DEBUG   : EnergyMeter  : {'cmin': 169.0, 'energy': 20930.48, 'pavg': 2071.25, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 180.0, 'pmax': 2200.0}
# 2017-08-04 17:23:31,628 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:23:43,987 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:23:43,997 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20590.35 pmax=2175.00 pavg=2037.59 pmin=2000.00 cmax=177.00 cmin=166.00 ]
# 2017-08-04 17:23:44,005 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:23:44,010 DEBUG   : EnergyMeter  : {'cmin': 166.0, 'energy': 20590.35, 'pavg': 2037.59, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:23:45,084 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:23:57,452 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:23:57,455 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20500.66 pmax=2175.00 pavg=2028.71 pmin=2000.00 cmax=177.00 cmin=166.00 ]
# 2017-08-04 17:23:57,469 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:23:57,476 DEBUG   : EnergyMeter  : {'cmin': 166.0, 'energy': 20500.66, 'pavg': 2028.71, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:23:58,552 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:24:10,892 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:24:10,898 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20657.68 pmax=2175.00 pavg=2044.25 pmin=2000.00 cmax=178.00 cmin=166.00 ]
# 2017-08-04 17:24:10,907 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:24:10,909 DEBUG   : EnergyMeter  : {'cmin': 166.0, 'energy': 20657.68, 'pavg': 2044.25, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 178.0, 'pmax': 2175.0}
# 2017-08-04 17:24:17,050 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:24:29,435 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:24:29,449 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20708.33 pmax=2175.00 pavg=2049.26 pmin=2000.00 cmax=177.00 cmin=166.00 ]
# 2017-08-04 17:24:29,457 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:24:29,460 DEBUG   : EnergyMeter  : {'cmin': 166.0, 'energy': 20708.33, 'pavg': 2049.26, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:24:30,535 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:24:42,892 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:24:42,895 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20627.63 pmax=2175.00 pavg=2041.28 pmin=2000.00 cmax=177.00 cmin=166.00 ]
# 2017-08-04 17:24:42,905 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:24:42,916 DEBUG   : EnergyMeter  : {'cmin': 166.0, 'energy': 20627.63, 'pavg': 2041.28, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:24:43,988 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:24:56,329 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:24:56,339 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20615.13 pmax=2175.00 pavg=2040.04 pmin=2000.00 cmax=177.00 cmin=166.00 ]
# 2017-08-04 17:24:56,342 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:24:56,346 DEBUG   : EnergyMeter  : {'cmin': 166.0, 'energy': 20615.13, 'pavg': 2040.04, 'pmin': 2000.0, 'vmax': 12193.75, 'cmax': 177.0, 'pmax': 2175.0}
# 2017-08-04 17:24:56,681 INFO    : root         : Cluster PD_1     (Online CPUs : [4, 5, 6])
# 2017-08-04 17:25:02,785 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:25:15,140 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:25:15,149 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21406.80 pmax=2250.00 pavg=2118.38 pmin=2100.00 cmax=185.00 cmin=173.00 ]
# 2017-08-04 17:25:15,160 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:25:15,161 DEBUG   : EnergyMeter  : {'cmin': 173.0, 'energy': 21406.8, 'pavg': 2118.38, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 185.0, 'pmax': 2250.0}
# 2017-08-04 17:25:16,237 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:25:28,575 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:25:28,585 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21417.11 pmax=2250.00 pavg=2119.40 pmin=2100.00 cmax=184.00 cmin=173.00 ]
# 2017-08-04 17:25:28,593 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:25:28,598 DEBUG   : EnergyMeter  : {'cmin': 173.0, 'energy': 21417.11, 'pavg': 2119.4, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 184.0, 'pmax': 2250.0}
# 2017-08-04 17:25:29,661 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:25:42,024 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:25:42,026 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21398.03 pmax=2250.00 pavg=2117.51 pmin=2100.00 cmax=185.00 cmin=173.00 ]
# 2017-08-04 17:25:42,033 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:25:42,034 DEBUG   : EnergyMeter  : {'cmin': 173.0, 'energy': 21398.03, 'pavg': 2117.51, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 185.0, 'pmax': 2250.0}
# 2017-08-04 17:25:48,280 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:26:00,632 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:26:00,643 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20962.28 pmax=2200.00 pavg=2074.39 pmin=2050.00 cmax=180.00 cmin=168.00 ]
# 2017-08-04 17:26:00,646 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:26:00,647 DEBUG   : EnergyMeter  : {'cmin': 168.0, 'energy': 20962.28, 'pavg': 2074.39, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 180.0, 'pmax': 2200.0}
# 2017-08-04 17:26:01,711 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:26:14,065 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:26:14,070 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20913.60 pmax=2200.00 pavg=2069.57 pmin=2050.00 cmax=180.00 cmin=168.00 ]
# 2017-08-04 17:26:14,079 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:26:14,081 DEBUG   : EnergyMeter  : {'cmin': 168.0, 'energy': 20913.6, 'pavg': 2069.57, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 180.0, 'pmax': 2200.0}
# 2017-08-04 17:26:15,164 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:26:27,518 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:26:27,529 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20888.60 pmax=2200.00 pavg=2067.10 pmin=2050.00 cmax=181.00 cmin=168.00 ]
# 2017-08-04 17:26:27,532 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:26:27,540 DEBUG   : EnergyMeter  : {'cmin': 168.0, 'energy': 20888.6, 'pavg': 2067.1, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 181.0, 'pmax': 2200.0}
# 2017-08-04 17:26:33,763 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:26:46,124 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:26:46,129 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20750.66 pmax=2175.00 pavg=2053.45 pmin=2050.00 cmax=179.00 cmin=167.00 ]
# 2017-08-04 17:26:46,139 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:26:46,141 DEBUG   : EnergyMeter  : {'cmin': 167.0, 'energy': 20750.66, 'pavg': 2053.45, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 179.0, 'pmax': 2175.0}
# 2017-08-04 17:26:47,212 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:26:59,557 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:26:59,569 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20744.74 pmax=2175.00 pavg=2052.86 pmin=2050.00 cmax=178.00 cmin=167.00 ]
# 2017-08-04 17:26:59,575 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:26:59,582 DEBUG   : EnergyMeter  : {'cmin': 167.0, 'energy': 20744.74, 'pavg': 2052.86, 'pmin': 2050.0, 'vmax': 12193.75, 'cmax': 178.0, 'pmax': 2175.0}
# 2017-08-04 17:27:00,702 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:27:13,049 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:27:13,056 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=20743.20 pmax=2175.00 pavg=2052.71 pmin=2025.00 cmax=178.00 cmin=167.00 ]
# 2017-08-04 17:27:13,065 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:27:13,068 DEBUG   : EnergyMeter  : {'cmin': 167.0, 'energy': 20743.2, 'pavg': 2052.71, 'pmin': 2025.0, 'vmax': 12193.75, 'cmax': 178.0, 'pmax': 2175.0}
# 2017-08-04 17:27:13,397 INFO    : root         : Cluster PD_1     (Online CPUs : [4, 5, 6, 7])
# 2017-08-04 17:27:19,409 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:27:31,757 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:27:31,759 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=22000.44 pmax=2300.00 pavg=2177.13 pmin=2150.00 cmax=188.00 cmin=177.00 ]
# 2017-08-04 17:27:31,763 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:27:31,768 DEBUG   : EnergyMeter  : {'cmin': 177.0, 'energy': 22000.44, 'pavg': 2177.13, 'pmin': 2150.0, 'vmax': 12192.5, 'cmax': 188.0, 'pmax': 2300.0}
# 2017-08-04 17:27:32,835 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:27:45,196 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:27:45,198 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12191.25 energy=21995.83 pmax=2300.00 pavg=2176.67 pmin=2150.00 cmax=188.00 cmin=176.00 ]
# 2017-08-04 17:27:45,205 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:27:45,210 DEBUG   : EnergyMeter  : {'cmin': 176.0, 'energy': 21995.83, 'pavg': 2176.67, 'pmin': 2150.0, 'vmax': 12191.25, 'cmax': 188.0, 'pmax': 2300.0}
# 2017-08-04 17:27:46,330 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:27:58,678 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:27:58,685 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21998.90 pmax=2300.00 pavg=2176.97 pmin=2150.00 cmax=189.00 cmin=177.00 ]
# 2017-08-04 17:27:58,694 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:27:58,696 DEBUG   : EnergyMeter  : {'cmin': 177.0, 'energy': 21998.9, 'pavg': 2176.97, 'pmin': 2150.0, 'vmax': 12192.5, 'cmax': 189.0, 'pmax': 2300.0}
# 2017-08-04 17:28:05,023 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:28:17,372 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:28:17,379 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21240.57 pmax=2200.00 pavg=2101.93 pmin=2100.00 cmax=183.00 cmin=170.00 ]
# 2017-08-04 17:28:17,388 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:28:17,396 DEBUG   : EnergyMeter  : {'cmin': 170.0, 'energy': 21240.57, 'pavg': 2101.93, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 183.0, 'pmax': 2200.0}
# 2017-08-04 17:28:18,496 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:28:30,832 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:28:30,845 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12193.75 energy=21239.91 pmax=2200.00 pavg=2101.87 pmin=2100.00 cmax=181.00 cmin=170.00 ]
# 2017-08-04 17:28:30,851 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:28:30,861 DEBUG   : EnergyMeter  : {'cmin': 170.0, 'energy': 21239.91, 'pavg': 2101.87, 'pmin': 2100.0, 'vmax': 12193.75, 'cmax': 181.0, 'pmax': 2200.0}
# 2017-08-04 17:28:31,966 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:28:44,346 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:28:44,353 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21239.25 pmax=2200.00 pavg=2101.80 pmin=2100.00 cmax=181.00 cmin=170.00 ]
# 2017-08-04 17:28:44,361 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:28:44,373 DEBUG   : EnergyMeter  : {'cmin': 170.0, 'energy': 21239.25, 'pavg': 2101.8, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 181.0, 'pmax': 2200.0}
# 2017-08-04 17:28:50,702 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:29:03,052 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:29:03,054 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21241.67 pmax=2200.00 pavg=2102.04 pmin=2100.00 cmax=182.00 cmin=170.00 ]
# 2017-08-04 17:29:03,055 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:29:03,057 DEBUG   : EnergyMeter  : {'cmin': 170.0, 'energy': 21241.67, 'pavg': 2102.04, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 182.0, 'pmax': 2200.0}
# 2017-08-04 17:29:04,154 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:29:16,521 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:29:16,524 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21240.57 pmax=2200.00 pavg=2101.93 pmin=2100.00 cmax=182.00 cmin=170.00 ]
# 2017-08-04 17:29:16,533 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:29:16,536 DEBUG   : EnergyMeter  : {'cmin': 170.0, 'energy': 21240.57, 'pavg': 2101.93, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 182.0, 'pmax': 2200.0}
# 2017-08-04 17:29:17,657 DEBUG   : EnergyMeter  : Started /usr/bin/iio-capture on Device0 (iio:device0)...
# 2017-08-04 17:29:30,025 DEBUG   : EnergyMeter  : Completed IIOCapture for Device0 (iio:device0)...
# 2017-08-04 17:29:30,032 DEBUG   : EnergyMeter  : Normal iio-capture case [vmax=12192.50 energy=21240.79 pmax=2200.00 pavg=2101.95 pmin=2100.00 cmax=182.00 cmin=170.00 ]
# 2017-08-04 17:29:30,035 DEBUG   : EnergyMeter  : Device0 (iio:device0)
# 2017-08-04 17:29:30,040 DEBUG   : EnergyMeter  : {'cmin': 170.0, 'energy': 21240.79, 'pavg': 2101.95, 'pmin': 2100.0, 'vmax': 12192.5, 'cmax': 182.0, 'pmax': 2200.0}
# 2017-08-04 17:29:30,068 DEBUG   : cgroups.freezer : Set attribute [/data/local/tmp/devlib-target/cgroups/devlib_cgh0/DEVLIB_FREEZER/freezer.state] to: THAWED"
# 2017-08-04 17:29:30,274 DEBUG   : root         : Moving all tasks into /
# 2017-08-04 17:29:30,281 DEBUG   : root         :    using grep filter:

# %%
idle_df
# Out:
#                                energy        power
# cluster idle_state cpus
# PD_0    0          1     13173.463333  1317.346333
#                    2     15529.383333  1552.938333
#                    3     15680.553333  1568.055333
#                    4     15685.670000  1568.567000
#         1          1     15440.936667  1544.093667
#                    2     15446.563333  1544.656333
#                    3     15435.743333  1543.574333
#                    4     15435.013333  1543.501333
#         2          1     12638.890000  1263.889000
#                    2     12425.656667  1242.565667
#                    3     15466.450000  1546.645000
#                    4     15467.616667  1546.761667
# PD_1    0          1     20233.920000  2023.392000
#                    2     20937.940000  2093.794000
#                    3     21407.313333  2140.731333
#                    4     21998.390000  2199.839000
#         1          1     20236.843333  2023.684333
#                    2     20582.896667  2058.289667
#                    3     20921.493333  2092.149333
#                    4     21239.910000  2123.991000
#         2          1     20354.606667  2035.460667
#                    2     20650.363333  2065.036333
#                    3     20746.200000  2074.620000
#                    4     21241.010000  2124.101000

# %% [markdown]
# ### Idle Power Statistics

# %%
WFI = 0
CORE_OFF = 1

def idle_power_stats(idle_df):
    """
    For each cluster compute per idle state power statistics.
    
    :param idle_df: dataframe containing power numbers
    :type idle_df: :mod:`pandas.DataFrame`
    """

    stats = []
    for cl in clusters:
        cl_df = idle_df.loc[cl.name].reset_index()
        # Start from deepest idle state
        cl_df = cl_df.sort_values('idle_state', ascending=False)
        grouped = cl_df.groupby('idle_state', sort=False)
        for state, df in grouped:
            energy = df.energy
            power = df.power
            state_name = "C{}_CLUSTER".format(state)
            if state == CORE_OFF:
                core_off_nrg_avg = energy.mean()
                core_off_pwr_avg = power.mean()
            if state == WFI:
                energy = df.energy.diff()
                energy[0] = df.energy[0] - core_off_nrg_avg
                power = df.power.diff()
                power[0] = df.power[0] - core_off_pwr_avg
                state_name = "C0_CORE"

            avg_row = {'cluster': cl.name,
                       'idle_state': state_name,
                       'stats': 'avg',
                       'energy': energy.mean(),
                       'power': power.mean()
                      }
            std_row = {'cluster': cl.name,
                       'idle_state': state_name,
                       'stats': 'std',
                       'energy': energy.std(),
                       'power': power.std()
                      }
            min_row = {'cluster' : cl.name,
                       'idle_state' : state_name,
                       'stats' : 'min',
                       'energy' : energy.min(),
                       'power' : power.min()
                      }
            max_row = {'cluster' : cl.name,
                       'idle_state' : state_name,
                       'stats' : 'max',
                       'energy' : energy.max(),
                       'power' : power.max()
                      }
            c99_row = {'cluster' : cl.name,
                       'idle_state' : state_name,
                       'stats' : 'c99',
                       'energy' : energy.quantile(q=0.99),
                       'power' : power.quantile(q=0.99)
                      }
            stats.append(avg_row)
            stats.append(std_row)
            stats.append(min_row)
            stats.append(max_row)
            stats.append(c99_row)
    
    stats_df = pd.DataFrame(stats).set_index(
        ['cluster', 'idle_state', 'stats']).sort_index(level='cluster')
    return stats_df.unstack()

# %%
idle_stats = idle_power_stats(idle_df)

# %% [markdown]
# ### Plotting Idle power

# %%
def plot_cstates(idle_power_df, cluster):
    """
    Plot C-States profiling for the specified cluster.
    
    :param idle_power_df: dataframe reporting power values in each idle state
    :type idle_power_df: :mod:`pandas.DataFrame`

    :param cluster: cluster description
    :type cluster: namedtuple(ClusterDescription)
    """
    n_cpus = len(cluster.cpus)
    cmap = ColorMap(len(cluster.idle_states))
    color_map = map(cmap.cmap, cluster.idle_states)
    color_map = [c for c in color_map for i in xrange(n_cpus)]

    cl_df = idle_power_df.loc[cluster.name]
    ax = cl_df.power.plot.bar(figsize=(16,8), color=color_map, alpha=0.5,
                              legend=False, table=True)

    idx = 0
    grouped = cl_df.groupby(level=0)
    for state, df in grouped:
        x = df.index.get_level_values('cpus').tolist()
        y = df.power.tolist()
        slope, intercept = linfit(x, y)

        y = [slope * v + intercept for v in x]
        x = range(n_cpus * idx, n_cpus * (idx + 1))
        ax.plot(x, y, color=color_map[idx*n_cpus], linewidth=4)
        idx += 1

    ax.grid(True)
    ax.get_xaxis().set_visible(False)
    ax.set_ylabel("Idle Power [$\mu$W]")
    ax.set_title("{} cluster C-states profiling"\
                 .format(cluster.name), fontsize=16)

# %%
pd0 = clusters[0]

plot_cstates(idle_df, pd0)

# %% [markdown]
# # Energy Model Generation

# %%
def pstates_model_df(clusters, pp_stats, power_perf_df, metric='avg'):
    """
    Build two data frames containing data to create the energy model for each
    cluster given as input.
    
    :param clusters: list of clusters to profile
    :type clusters: list(namedtuple(ClusterDescription))
    
    :param pp_stats: power and performance statistics
    :type pp_stats: :mod:`pandas.DataFrame`
    
    :param power_perf_df: power and performance data
    :type power_perf_df: :mod:`pandas.DataFrame`
    """
    max_score = pp_stats.perf[metric].max()

    core_cap_energy = []
    cluster_cap_energy = []
    for cl in clusters:
        # ACTIVE Energy
        grouped = power_perf_df.loc[cl.name].groupby(level='freq')
        for freq, df in grouped:
            # Get average energy at OPP freq for 1 CPU
            energy_freq_1 = pp_stats.loc[cl.name].loc[freq]['energy'][metric]
            # Get cluster energy at OPP freq
            x = df.index.get_level_values('cpus').tolist()
            y = df.energy.tolist()
            slope, intercept = linfit(x, y)
            # Energy can't be negative but the regression line may intercept the
            # y-axis at a negative value. Im this case cluster energy can be
            # assumed to be 0.
            cluster_energy = intercept if intercept >= 0.0 else 0.0
            core_energy = energy_freq_1 - cluster_energy
            #core_energy = cluster_energy

            # Get score at OPP freq
            score_freq = pp_stats.loc[cl.name].loc[freq]['perf'][metric]
            capacity = int(score_freq * 1024 / max_score)

            core_cap_energy.append({'cluster' : cl.name,
                                    'core': cl.core_name,
                                    'freq': freq,
                                    'cap': capacity,
                                    'energy': core_energy})
            cluster_cap_energy.append({'cluster': cl.name,
                                       'freq': freq,
                                       'cap': capacity,
                                       'energy': cluster_energy})

    core_cap_nrg_df = pd.DataFrame(core_cap_energy)
    cluster_cap_nrg_df = pd.DataFrame(cluster_cap_energy)
    return core_cap_nrg_df, cluster_cap_nrg_df

# %%
core_cap_nrg_df, cluster_cap_nrg_df = pstates_model_df(clusters,
                                                       pp_stats,
                                                       power_perf_df,
                                                       metric='avg'
                                                      )

# %%
core_cap_nrg_df
# Out:
#     cap cluster      core        energy     freq
# 0   287    PD_0  A53_PD_0  -4367.462986   533000
# 1   540    PD_0  A53_PD_0  -3008.140486   999000
# 2   731    PD_0  A53_PD_0  -3390.734028  1402000
# 3   841    PD_0  A53_PD_0  -6676.230208  1709000
# 4   877    PD_0  A53_PD_0  -8514.494931  1844000
# 5   523    PD_1  A73_PD_1  -6181.172569   903000
# 6   780    PD_1  A73_PD_1  -8049.433472  1421000
# 7   884    PD_1  A73_PD_1 -10255.451250  1805000
# 8   961    PD_1  A73_PD_1 -14285.683819  2112000
# 9  1024    PD_1  A73_PD_1 -19430.454306  2362000

# %% [markdown]
# In this case, taking the average energy consumed by a core does not provide a nice result because the energy measured while running with $n$ CPUs **is not** $n \times Energy\_of\_one\_CPU$.
#
# For this reason, we will use a different metric, like for instance the 99th percentile.

# %%
core_cap_nrg_df, cluster_cap_nrg_df = pstates_model_df(clusters,
                                                       pp_stats,
                                                       power_perf_df,
                                                       metric='c99'
                                                      )

# %%
core_cap_nrg_df
# Out:
#     cap cluster      core       energy     freq
# 0   227    PD_0  A53_PD_0  3089.450900   533000
# 1   426    PD_0  A53_PD_0  1515.602717   999000
# 2   599    PD_0  A53_PD_0  2177.474000  1402000
# 3   731    PD_0  A53_PD_0   213.922200  1709000
# 4   788    PD_0  A53_PD_0 -1141.993417  1844000
# 5   413    PD_1  A73_PD_1  1406.683150   903000
# 6   651    PD_1  A73_PD_1    58.272300  1421000
# 7   808    PD_1  A73_PD_1 -1366.811067  1805000
# 8   961    PD_1  A73_PD_1 -4288.456617  2112000
# 9  1024    PD_1  A73_PD_1 -6500.034867  2362000

# %%
cluster_cap_nrg_df
# Out:
#     cap cluster        energy     freq
# 0   227    PD_0  12690.131667   533000
# 1   426    PD_0   9945.066667   999000
# 2   599    PD_0  11415.276667  1402000
# 3   731    PD_0  16264.948333  1709000
# 4   788    PD_0  18283.333333  1844000
# 5   413    PD_1  16346.126667   903000
# 6   651    PD_1  19417.140000  1421000
# 7   808    PD_1  22867.583333  1805000
# 8   961    PD_1  28881.033333  2112000
# 9  1024    PD_1  36978.836667  2362000

# %%
def energy_model_dict(clusters, core_cap_nrg_df, cluster_cap_nrg_df, metric='avg'):
    n_states = len(clusters[0].idle_states)

    nrg_dict = {}

    grouped = core_cap_nrg_df.groupby('cluster')
    for cl, df in grouped:
        nrg_dict[cl] = {
            "opps" : {},
            "core": {
                "name": df.core.iloc[0],
                "busy-cost": OrderedDict(),
                "idle-cost": OrderedDict()
            },
            "cluster": {
                "busy-cost": OrderedDict(),
                "idle-cost": OrderedDict()
            }
        }
        # Core COSTS
        # ACTIVE costs
        for row in df.iterrows():
            nrg_dict[cl]["opps"][row[1].cap] = row[1].freq
            nrg_dict[cl]["core"]["busy-cost"][row[1].cap] = int(row[1].energy*100)

        # IDLE costs
        wfi_nrg = idle_stats.loc[cl].energy[metric][0]
        # WFI
        nrg_dict[cl]["core"]["idle-cost"][0] = int(wfi_nrg*100)
        # All remaining states are zeroes
        for i in xrange(1, n_states):
            nrg_dict[cl]["core"]["idle-cost"][i] = 0

        # Cluster COSTS
        cl_data = cluster_cap_nrg_df[cluster_cap_nrg_df.cluster == cl]
        # ACTIVE costs
        for row in cl_data.iterrows():
            nrg_dict[cl]["cluster"]["busy-cost"][row[1].cap] = int(row[1].energy*100)

        # IDLE costs
        # Core OFF is the first valid idle cost for cluster
        idle_data = idle_stats.loc[cl].energy[metric]
        # WFI (same as Core OFF)
        nrg_dict[cl]["cluster"]["idle-cost"][0] = int(idle_data[1]*100)
        # All other idle states (from CORE OFF down)
        for i in xrange(1, n_states):
            nrg_dict[cl]["cluster"]["idle-cost"][i] = int(idle_data[i]*100)

    return nrg_dict

# %%
nrg_dict = energy_model_dict(clusters, core_cap_nrg_df, cluster_cap_nrg_df)

# %% [markdown]
# ## Device Tree EM Format

# %%
def dump_device_tree(nrg_dict, outfile='sched-energy.dtsi'):
    """
    Generate device tree energy model file.
    
    :param nrg_dict: dictionary describing the energy model
    :type nrg_dict: dict
    
    :param outfile: output file name
    :type outfile: str
    """
    with open(os.path.join(te.res_dir, outfile), 'w') as out:
        out.write("energy-costs {\n")
        idx = 0
        for cl_name in nrg_dict.keys():
            core = nrg_dict[cl_name]["core"]
            # Dump Core costs
            out.write("\tCPU_COST_{}: core_cost{} {}\n"\
                      .format(core["name"], idx, '{'))
            # ACTIVE costs
            out.write("\t\tbusy-cost-data = <\n")
            for cap, nrg in core["busy-cost"].iteritems():
                out.write("\t\t\t{} {}\n".format(cap, nrg))
            out.write("\t\t>;\n")
            # IDLE costs
            out.write("\t\tidle-cost-data = <\n")
            # arch idle
            out.write("\t\t\t{}\n".format(core["idle-cost"][0]))
            for nrg in core["idle-cost"].values():
                out.write("\t\t\t{}\n".format(nrg)) 
            out.write("\t\t>;\n")
            out.write("\t};\n")

            # Dump Cluster costs
            cl = nrg_dict[cl_name]["cluster"]
            out.write("\tCLUSTER_COST_{}: cluster_cost{} {}\n"\
                      .format(cl_name, idx, '{'))
            # ACTIVE costs
            out.write("\t\tbusy-cost-data = <\n")
            for cap, nrg in cl["busy-cost"].iteritems():
                out.write("\t\t\t{} {}\n".format(cap, nrg))
            out.write("\t\t>;\n")
            # IDLE costs
            out.write("\t\tidle-cost-data = <\n")
            # arch idle
            out.write("\t\t\t{}\n".format(cl["idle-cost"][0]))
            for nrg in cl["idle-cost"].values():
                out.write("\t\t\t{}\n".format(nrg))
            out.write("\t\t>;\n")
            out.write("\t};\n")
            idx += 1
        out.write("};")

# %% [markdown]
# ## C Code EM Format

# %%
def dump_c_code(nrg_dict, cluster_ids, outfile='energy_model.c'):
    """
    Generate C code energy model file.
    
    :param nrg_dict: dictionary describing the energy model
    :type nrg_dict: dict
    
    :param cluster_ids: mapping between cluster names and cluster IDs
    :type cluster_ids: dict
    
    :param outfile: output file name
    :type outfile: str
    """
    with open(os.path.join(te.res_dir, outfile), 'w') as o:

        core_names = []
        for cl_name in nrg_dict.keys():
            # Dump Core data
            core = nrg_dict[cl_name]["core"]
            core_names.append(core["name"])
            o.write("static struct capacity_state cap_states_core_{}[] = {}\n"\
                    .format(core["name"], '{'))
            o.write("\t/* Power per CPU */\n")
            for cap, nrg in core["busy-cost"].iteritems():
                o.write("\t {{ .cap = {:5d}, .power = {:5d}, }},\n"\
                        .format(cap, nrg))
            o.write("\t};\n")

            o.write("\n")

            o.write("static struct idle_state idle_states_core_{}[] = {}\n"\
                    .format(core["name"], '{'))
            # arch idle (same as WFI)
            o.write("\t {{ .power = {:5d}, }},\n".format(core["idle-cost"][0]))
            for nrg in core["idle-cost"].values():
                o.write("\t {{ .power = {:5d}, }},\n".format(nrg))
            o.write("\t};\n")

            o.write("\n")

            # Dump Cluster data
            cl = nrg_dict[cl_name]["cluster"]
            o.write("static struct capacity_state cap_states_cluster_{}[] = {}\n"\
                    .format(cl_name, '{'))
            o.write("\t/* Power per cluster */\n")
            for cap, nrg in cl["busy-cost"].iteritems():
                o.write("\t {{ .cap = {:5d}, .power = {:5d}, }},\n"\
                        .format(cap, nrg))
            o.write("\t};\n")

            o.write("\n")

            o.write("static struct idle_state idle_states_cluster_{}[] = {}\n"\
                    .format(cl_name, '{'))
            # arch idle (same as Core OFF)
            o.write("\t {{ .power = {:5d}, }},\n".format(cl["idle-cost"][0]))
            for nrg in cl["idle-cost"].values():
                o.write("\t {{ .power = {:5d}, }},\n".format(nrg))
            o.write("\t};\n")

            o.write("\n")

            o.write("static struct sched_group_energy energy_cluster_{} = {}\n"\
                    .format(core["name"], '{'))
            o.write("\t.nr_idle_states = ARRAY_SIZE(idle_states_cluster_{}),\n"\
                    .format(core["name"]))
            o.write("\t.idle_states    = idle_states_cluster_{},\n"\
                    .format(core["name"]))
            o.write("\t.nr_cap_states  = ARRAY_SIZE(cap_states_cluster_{}),\n"\
                    .format(core["name"]))
            o.write("\t.cap_states     = cap_states_cluster_{},\n"\
                    .format(core["name"]))
            o.write("};\n")

            o.write("\n")

        # Array of pointers to CORE sched_group_energy structs
        o.write("static struct sched_group_energy *energy_cores[] = {\n")
        for cl_name in cluster_ids.values():
            o.write("\t&energy_core_{},\n"\
                    .format(nrg_dict[cl_name]["core"]["name"]))
        o.write("};\n")

        o.write("\n")

        # Array of pointers to CLUSTER sched_group_energy structs
        o.write("static struct sched_group_energy *energy_clusters[] = {\n")
        for name in cluster_ids.values():
            o.write("\t&energy_cluster_{},\n".format(name))
        o.write("};\n")

        o.write("\n")

        o.write("static inline\n")
        o.write("const struct sched_group_energy * const cpu_core_energy(int cpu)\n")
        o.write("{\n")
        o.write("\treturn energy_cores[cpu_topology[cpu].cluster_id];\n")
        o.write("}\n")

        o.write("\n")

        o.write("static inline\n")
        o.write("const struct sched_group_energy * const cpu_cluster_energy(int cpu)\n")
        o.write("{\n")
        o.write("\treturn energy_clusters[cpu_topology[cpu].cluster_id];\n")
        o.write("}\n")

# %% [markdown]
# ## JSON EM Format

# %%
def dump_json(nrg_dict, outfile='energy_model.json'):
    """
    Generate JSON energy model file.
    
    :param nrg_dict: dictionary describing the energy model
    :type nrg_dict: dict
    
    :param outfile: output file name
    :type outfile: str
    """
    with open(os.path.join(te.res_dir, outfile), 'w') as ofile:
        json.dump(nrg_dict, ofile, sort_keys=True, indent=4)

# %%
dump_device_tree(nrg_dict)

# %%
# !ls -al
#!cat ./sched-energy.dtsi
# Out:
# total 780
# drwxrwxr-x 3 zhifei zhifei   4096 8月   4 17:37 .
# drwxrwxr-x 9 zhifei zhifei   4096 8月   3 00:02 ..
# -rw-rw-r-- 1 zhifei zhifei   1034 8月   4 17:29 cstates.csv
# -rw-rw-r-- 1 zhifei zhifei 367214 8月   4 17:37 EnergyModel_hikey960.ipynb
# drwxr-xr-x 2 zhifei zhifei   4096 7月  13 17:14 .ipynb_checkpoints
# -rw-rw-r-- 1 zhifei zhifei 402595 8月   4 17:29 lisa.log
# -rw-rw-r-- 1 zhifei zhifei   2430 8月   4 17:06 pstates.csv

# %%
dtsi = os.path.join(te.res_dir, "sched-energy.dtsi")


# !dir nrg_dict
# Out:
# dir: cannot access 'nrg_dict': No such file or directory
